# %%
# https://spotipy.readthedocs.io/en/2.19.0/

# Install spotipy
# As google colab starts each session like a new computer, we must install this each time.
# If you are working on your local machine, you only need to install it once.
# !pip install spotipy --upgrade
# !pip install urllib3 --upgrade
# Out:
# Requirement already satisfied: spotipy in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (2.23.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.15)
# Requirement already satisfied: requests>=2.25.0 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: six>=1.15.0 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: redis>=3.5.3 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (4.5.4)
# Requirement already satisfied: async-timeout>=4.0.2 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: urllib3 in /Users/Priyatam/opt/anaconda3/lib/python3.9/site-packages (1.26.15)

# %%
import pandas as pd

# %% [markdown]
# ## Requests
#
# The requests library is the de facto standard for making HTTP requests in Python. It abstracts the complexities of making requests behind a beautiful, simple API so that you can focus on interacting with services and consuming data in your application.
#
# https://requests.readthedocs.io/en/latest/
#
# When we make a request, we get a requests.Response object in return. The requests.Response object contains the server's response to the HTTP request. Part of this response is a number - which represents whether we received the information we wanted or not. If you get a number that you don't understand, these cats will help you: https://http.cat/
#
# More often than not you'll receive:
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

wbscs = requests.get("https://www.wbscodingschool.com/")
print("WBS CS: ", wbscs.status_code)
# Out:
# Google: 200
# NBA: 401
# WBS CS:  403

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Intro - making a request and viewing the JSON
#
# https://docs.python.org/3/library/json.html
#
# Since its inception, JSON has quickly become the de facto standard for information exchange. JSON supports primitive types, like strings and numbers, as well as nested lists and objects. It looks like nested python dictionaries:
#
# `{"firstname": "Harry",
# "lastname": "Noah",
# "city": "Berlin",
# "dogs": [{"name": "rover", "breed": "labrador"}, {"name": "pip", "breed": "spaniel"}],
# "cars": "none"}`

# %%
import json

# %%
# Make the request.
response = requests.get("https://jsonplaceholder.typicode.com/users")

# %%
# Check the HTTP code.
response
# Out:
# <Response [200]>

# %%
# Example of what a JSON looks like.

# View API response as a JSON.
response.json()
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
#  {'id': 3,
#   'name': 'Clementine Bauch',
#   'username': 'Samantha',
#   'email': 'Nathan@yesenia.net',
#   'address': {'street': 'Douglas Extension',
#    'suite': 'Suite 847',
#    'city': 'McKenziehaven',
#    'zipcode': '59590-4157',
#    'geo': {'lat': '-68.6102', 'lng': '-47.0653'}},
#   'phone': '1-463-123-4447',
#   'website': 'ramiro.info',
#   'company': {'name': 'Romaguera-Jacobson',
#    'catchPhrase': 'Face to face bifurcated interface',
#    'bs': 'e-enable strategic applications'}},
#  {'id': 4,
#   'name': 'Patricia Lebsack',
#   'username': 'Karianne',
#   'email': 'Julianne.OConner@kory.org',
#   'address': {'street': 'Hoeger Mall',
#    'suite': 'Apt. 692',
#    'city': 'South Elvis',
#    'zipcode': '53919-4257',
#    'geo': {'lat': '29.4572', 'lng': '-164.2990'}},
#   'phone': '493-170-9623 x156',
#   'website': 'kale.biz',
#   'company': {'name': 'Robel-Corkery',
#    'catchPhrase': 'Multi-tiered zero tolerance productivity',
#    'bs': 'transition cutting-edge web services'}},
#  {'id': 5,
#   'name': 'Chelsey Dietrich',
#   'username': 'Kamren',
#   'email': 'Lucio_Hettinger@annie.ca',
#   'address': {'street': 'Skiles Walks',
#    'suite': 'Suite 351',
#    'city': 'Roscoeview',
#    'zipcode': '33263',
#    'geo': {'lat': '-31.8129', 'lng': '62.5342'}},
#   'phone': '(254)954-1289',
#   'website': 'demarco.info',
#   'company': {'name': 'Keebler LLC',
#    'catchPhrase': 'User-centric fault-tolerant solution',
#    'bs': 'revolutionize end-to-end systems'}},
#  {'id': 6,
#   'name': 'Mrs. Dennis Schulist',
#   'username': 'Leopoldo_Corkery',
#   'email': 'Karley_Dach@jasper.info',
#   'address': {'street': 'Norberto Crossing',
#    'suite': 'Apt. 950',
#    'city': 'South Christy',
#    'zipcode': '23505-1337',
#    'geo': {'lat': '-71.4197', 'lng': '71.7478'}},
#   'phone': '1-477-935-8478 x6430',
#   'website': 'ola.org',
#   'company': {'name': 'Considine-Lockman',
#    'catchPhrase': 'Synchronised bottom-line interface',
#    'bs': 'e-enable innovative applications'}},
#  {'id': 7,
#   'name': 'Kurtis Weissnat',
#   'username': 'Elwyn.Skiles',
#   'email': 'Telly.Hoeger@billy.biz',
#   'address': {'street': 'Rex Trail',
#    'suite': 'Suite 280',
#    'city': 'Howemouth',
#    'zipcode': '58804-1099',
#    'geo': {'lat': '24.8918', 'lng': '21.8984'}},
#   'phone': '210.067.6132',
#   'website': 'elvis.io',
#   'company': {'name': 'Johns Group',
#    'catchPhrase': 'Configurable multimedia task-force',
#    'bs': 'generate enterprise e-tailers'}},
#  {'id': 8,
#   'name': 'Nicholas Runolfsdottir V',
#   'username': 'Maxime_Nienow',
#   'email': 'Sherwood@rosamond.me',
#   'address': {'street': 'Ellsworth Summit',
#    'suite': 'Suite 729',
#    'city': 'Aliyaview',
#    'zipcode': '45169',
#    'geo': {'lat': '-14.3990', 'lng': '-120.7677'}},
#   'phone': '586.493.6943 x140',
#   'website': 'jacynthe.com',
#   'company': {'name': 'Abernathy Group',
#    'catchPhrase': 'Implemented secondary concept',
#    'bs': 'e-enable extensible e-tailers'}},
#  {'id': 9,
#   'name': 'Glenna Reichert',
#   'username': 'Delphine',
#   'email': 'Chaim_McDermott@dana.io',
#   'address': {'street': 'Dayna Park',
#    'suite': 'Suite 449',
#    'city': 'Bartholomebury',
#    'zipcode': '76495-3109',
#    'geo': {'lat': '24.6463', 'lng': '-168.8889'}},
#   'phone': '(775)976-6794 x41206',
#   'website': 'conrad.com',
#   'company': {'name': 'Yost and Sons',
#    'catchPhrase': 'Switchable contextually-based project',
#    'bs': 'aggregate real-time technologies'}},
#  {'id': 10,
#   'name': 'Clementina DuBuque',
#   'username': 'Moriah.Stanton',
#   'email': 'Rey.Padberg@karina.biz',
#   'address': {'street': 'Kattie Turnpike',
#    'suite': 'Suite 198',
#    'city': 'Lebsackbury',
#    'zipcode': '31428-2261',
#    'geo': {'lat': '-38.2386', 'lng': '57.2232'}},
#   'phone': '024-648-3804',
#   'website': 'ambrose.net',
#   'company': {'name': 'Hoeger LLC',
#    'catchPhrase': 'Centralized empowering task-force',
#    'bs': 'target end-to-end models'}}]

# %% [markdown]
# ### GitHub API - Accessing the data in the JSON
#
# Now that we know
# - what an API is,
# - how to request information from one (requests),
# - how the information will be delivered to us (JSON):
#
# Let's look how we can use this information. We will first look at how we can access particular values within the JSON. Then we will look at a couple of methods to make a dataframe from the JSON.
#
# Github has many APIs. Here we'll look at two of them.

# %%
# Very basic API (a string returned).

# GitHub's Zen API produces a new inspirational phrase every 30 seconds.
# Run this cell again in 30 seconds to see a different output.

resp = requests.get("https://api.github.com/zen")
resp.text
# Out:
# 'Speak like a human.'

# %%
# More complex API (a large json returned).

# Github's Event API shows the events that power the various activity streams on the site.
# In other words, what's happening on Github, who's updating what?

response = requests.get('https://api.github.com/events')
github_response = response.json()
github_response
# Out:
# [{'id': '28470051881',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 18215579,
#    'login': 'CaptainStandby',
#    'display_login': 'CaptainStandby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CaptainStandby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18215579?'},
#   'repo': {'id': 135321861,
#    'name': 'ory/kratos',
#    'url': 'https://api.github.com/repos/ory/kratos'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/ory/kratos/pulls/comments/1168962847',
#     'pull_request_review_id': 1388468413,
#     'id': 1168962847,
#     'node_id': 'PRRC_kwDOCBDZBc5FrPUf',
#     'diff_hunk': '@@ -198,6 +202,16 @@ func (h *Handler) performNativeLogout(w http.ResponseWriter, r *http.Request, _\n \t\th.d.Writer().WriteError(w, r, err)\n \t\treturn\n \t}\n+\tsess, err := h.d.SessionPersister().GetSessionByToken(r.Context(), p.SessionToken, session.ExpandNothing, identity.ExpandNothing)\n+\tif err != nil {\n+\t\tif errors.Is(err, sqlcon.ErrNoRows) {\n+\t\t\th.d.Writer().WriteError(w, r, errors.WithStack(herodot.ErrForbidden.WithReason("The provided Ory Session Token could not be found, is invalid, or otherwise malformed.")))\n+\t\t\treturn\n+\t\t}\n+\n+\t\th.d.Writer().WriteError(w, r, err)\n+\t\treturn\n+\t}',
#     'path': 'selfservice/flow/logout/handler.go',
#     'commit_id': '99248f3abcec54870a6aeca0c7497ed14ab90c86',
#     'original_commit_id': '99248f3abcec54870a6aeca0c7497ed14ab90c86',
#     'user': {'login': 'CaptainStandby',
#      'id': 18215579,
#      'node_id': 'MDQ6VXNlcjE4MjE1NTc5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18215579?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CaptainStandby',
#      'html_url': 'https://github.com/CaptainStandby',
#      'followers_url': 'https://api.github.com/users/CaptainStandby/followers',
#      'following_url': 'https://api.github.com/users/CaptainStandby/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CaptainStandby/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CaptainStandby/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CaptainStandby/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CaptainStandby/orgs',
#      'repos_url': 'https://api.github.com/users/CaptainStandby/repos',
#      'events_url': 'https://api.github.com/users/CaptainStandby/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CaptainStandby/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Not 100% sure it's a good idea to load the session just so we can attach some metadata to the event (Line 226). Is there maybe a less invasive way of getting this data here?",
#     'created_at': '2023-04-17T16:03:39Z',
#     'updated_at': '2023-04-17T16:07:54Z',
#     'html_url': 'https://github.com/ory/kratos/pull/3235#discussion_r1168962847',
#     'pull_request_url': 'https://api.github.com/repos/ory/kratos/pulls/3235',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/ory/kratos/pulls/comments/1168962847'},
#      'html': {'href': 'https://github.com/ory/kratos/pull/3235#discussion_r1168962847'},
#      'pull_request': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235'}},
#     'reactions': {'url': 'https://api.github.com/repos/ory/kratos/pulls/comments/1168962847/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': 205,
#     'original_start_line': 205,
#     'start_side': 'RIGHT',
#     'line': 214,
#     'original_line': 214,
#     'side': 'RIGHT',
#     'original_position': 24,
#     'position': 24,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/ory/kratos/pulls/3235',
#     'id': 1312895676,
#     'node_id': 'PR_kwDOCBDZBc5OQTK8',
#     'html_url': 'https://github.com/ory/kratos/pull/3235',
#     'diff_url': 'https://github.com/ory/kratos/pull/3235.diff',
#     'patch_url': 'https://github.com/ory/kratos/pull/3235.patch',
#     'issue_url': 'https://api.github.com/repos/ory/kratos/issues/3235',
#     'number': 3235,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat: emit events for login/logout and registration',
#     'user': {'login': 'CaptainStandby',
#      'id': 18215579,
#      'node_id': 'MDQ6VXNlcjE4MjE1NTc5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18215579?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CaptainStandby',
#      'html_url': 'https://github.com/CaptainStandby',
#      'followers_url': 'https://api.github.com/users/CaptainStandby/followers',
#      'following_url': 'https://api.github.com/users/CaptainStandby/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CaptainStandby/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CaptainStandby/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CaptainStandby/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CaptainStandby/orgs',
#      'repos_url': 'https://api.github.com/users/CaptainStandby/repos',
#      'events_url': 'https://api.github.com/users/CaptainStandby/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CaptainStandby/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "<!--\r\nDescribe the big picture of your changes here to communicate to the maintainers why we should accept this pull request.\r\n\r\nThis text will be included in the changelog. If applicable, include links to documentation or pieces of code.\r\nIf your change includes breaking changes please add a code block documenting the breaking change:\r\n\r\n```\r\nBREAKING CHANGES: This patch changes the behavior of configuration item `foo` to do bar. To keep the existing\r\nbehavior please do baz.\r\n```\r\n-->\r\n\r\n## Related issue(s)\r\n\r\n<!--\r\nIf this pull request\r\n\r\n1. is a fix for a known bug, link the issue where the bug was reported in the format of `#1234`;\r\n2. is a fix for a previously unknown bug, explain the bug and how to reproduce it in this pull request;\r\n3. implements a new feature, link the issue containing the design document in the format of `#1234`;\r\n4. improves the documentation, no issue reference is required.\r\n\r\nPull requests introducing new features, which do not have a design document linked are more likely to be rejected and take on average 2-8 weeks longer to\r\nget merged.\r\n\r\nYou can discuss changes with maintainers either in the Github Discussions in this repository or\r\njoin the [Ory Chat](https://www.ory.sh/chat).\r\n-->\r\n\r\n## Checklist\r\n\r\n<!--\r\nPut an `x` in the boxes that apply. You can also fill these out after creating the PR.\r\n\r\nPlease be aware that pull requests must have all boxes ticked in order to be merged.\r\n\r\nIf you're unsure about any of them, don't hesitate to ask. We're here to help!\r\n-->\r\n\r\n- [x] I have read the [contributing guidelines](../blob/master/CONTRIBUTING.md).\r\n- [ ] I have referenced an issue containing the design document if my change\r\n      introduces a new feature.\r\n- [x] I am following the\r\n      [contributing code guidelines](../blob/master/CONTRIBUTING.md#contributing-code).\r\n- [x] I have read the [security policy](../security/policy).\r\n- [x] I confirm that this pull request does not address a security\r\n      vulnerability. If this pull request addresses a security vulnerability, I\r\n      confirm that I got the approval (please contact\r\n      [security@ory.sh](mailto:security@ory.sh)) from the maintainers to push\r\n      the changes.\r\n- [ ] I have added tests that prove my fix is effective or that my feature\r\n      works.\r\n- [ ] I have added or changed [the documentation](https://github.com/ory/docs).\r\n\r\n## Further Comments\r\n\r\n<!--\r\nIf this is a relatively large or complex change, kick off the discussion by explaining why you chose the solution\r\nyou did and what alternatives you considered, etc...\r\n-->\r\n",
#     'created_at': '2023-04-13T17:32:54Z',
#     'updated_at': '2023-04-17T16:07:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '61cc2f3128b38d0a0cbd15dbf81a0ef975de99f4',
#     'assignee': {'login': 'CaptainStandby',
#      'id': 18215579,
#      'node_id': 'MDQ6VXNlcjE4MjE1NTc5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18215579?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CaptainStandby',
#      'html_url': 'https://github.com/CaptainStandby',
#      'followers_url': 'https://api.github.com/users/CaptainStandby/followers',
#      'following_url': 'https://api.github.com/users/CaptainStandby/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CaptainStandby/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CaptainStandby/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CaptainStandby/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CaptainStandby/orgs',
#      'repos_url': 'https://api.github.com/users/CaptainStandby/repos',
#      'events_url': 'https://api.github.com/users/CaptainStandby/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CaptainStandby/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'CaptainStandby',
#       'id': 18215579,
#       'node_id': 'MDQ6VXNlcjE4MjE1NTc5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18215579?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CaptainStandby',
#       'html_url': 'https://github.com/CaptainStandby',
#       'followers_url': 'https://api.github.com/users/CaptainStandby/followers',
#       'following_url': 'https://api.github.com/users/CaptainStandby/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CaptainStandby/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CaptainStandby/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CaptainStandby/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CaptainStandby/orgs',
#       'repos_url': 'https://api.github.com/users/CaptainStandby/repos',
#       'events_url': 'https://api.github.com/users/CaptainStandby/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CaptainStandby/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [{'login': 'aeneasr',
#       'id': 3372410,
#       'node_id': 'MDQ6VXNlcjMzNzI0MTA=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3372410?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aeneasr',
#       'html_url': 'https://github.com/aeneasr',
#       'followers_url': 'https://api.github.com/users/aeneasr/followers',
#       'following_url': 'https://api.github.com/users/aeneasr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aeneasr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aeneasr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aeneasr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aeneasr/orgs',
#       'repos_url': 'https://api.github.com/users/aeneasr/repos',
#       'events_url': 'https://api.github.com/users/aeneasr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aeneasr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'zepatrik',
#       'id': 5354445,
#       'node_id': 'MDQ6VXNlcjUzNTQ0NDU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5354445?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zepatrik',
#       'html_url': 'https://github.com/zepatrik',
#       'followers_url': 'https://api.github.com/users/zepatrik/followers',
#       'following_url': 'https://api.github.com/users/zepatrik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zepatrik/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zepatrik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zepatrik/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zepatrik/orgs',
#       'repos_url': 'https://api.github.com/users/zepatrik/repos',
#       'events_url': 'https://api.github.com/users/zepatrik/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zepatrik/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ory/kratos/pulls/3235/commits',
#     'review_comments_url': 'https://api.github.com/repos/ory/kratos/pulls/3235/comments',
#     'review_comment_url': 'https://api.github.com/repos/ory/kratos/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ory/kratos/issues/3235/comments',
#     'statuses_url': 'https://api.github.com/repos/ory/kratos/statuses/99248f3abcec54870a6aeca0c7497ed14ab90c86',
#     'head': {'label': 'ory:hf/metrics_1',
#      'ref': 'hf/metrics_1',
#      'sha': '99248f3abcec54870a6aeca0c7497ed14ab90c86',
#      'user': {'login': 'ory',
#       'id': 25334553,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ory',
#       'html_url': 'https://github.com/ory',
#       'followers_url': 'https://api.github.com/users/ory/followers',
#       'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ory/orgs',
#       'repos_url': 'https://api.github.com/users/ory/repos',
#       'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ory/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 135321861,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzUzMjE4NjE=',
#       'name': 'kratos',
#       'full_name': 'ory/kratos',
#       'private': False,
#       'owner': {'login': 'ory',
#        'id': 25334553,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ory',
#        'html_url': 'https://github.com/ory',
#        'followers_url': 'https://api.github.com/users/ory/followers',
#        'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ory/orgs',
#        'repos_url': 'https://api.github.com/users/ory/repos',
#        'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ory/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ory/kratos',
#       'description': 'Next-gen identity server (think Auth0, Okta, Firebase) with Ory-hardened authentication, MFA, FIDO2, TOTP, WebAuthn, profile management, identity schemas, social sign in, registration, account recovery, passwordless. Golang, headless, API-only - without templating or theming headaches. Available as a cloud service.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ory/kratos',
#       'forks_url': 'https://api.github.com/repos/ory/kratos/forks',
#       'keys_url': 'https://api.github.com/repos/ory/kratos/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ory/kratos/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ory/kratos/teams',
#       'hooks_url': 'https://api.github.com/repos/ory/kratos/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ory/kratos/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ory/kratos/events',
#       'assignees_url': 'https://api.github.com/repos/ory/kratos/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ory/kratos/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ory/kratos/tags',
#       'blobs_url': 'https://api.github.com/repos/ory/kratos/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ory/kratos/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ory/kratos/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ory/kratos/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ory/kratos/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ory/kratos/languages',
#       'stargazers_url': 'https://api.github.com/repos/ory/kratos/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ory/kratos/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ory/kratos/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ory/kratos/subscription',
#       'commits_url': 'https://api.github.com/repos/ory/kratos/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ory/kratos/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ory/kratos/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ory/kratos/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ory/kratos/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ory/kratos/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ory/kratos/merges',
#       'archive_url': 'https://api.github.com/repos/ory/kratos/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ory/kratos/downloads',
#       'issues_url': 'https://api.github.com/repos/ory/kratos/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ory/kratos/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ory/kratos/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ory/kratos/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ory/kratos/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ory/kratos/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ory/kratos/deployments',
#       'created_at': '2018-05-29T16:09:37Z',
#       'updated_at': '2023-04-17T11:36:21Z',
#       'pushed_at': '2023-04-17T14:46:49Z',
#       'git_url': 'git://github.com/ory/kratos.git',
#       'ssh_url': 'git@github.com:ory/kratos.git',
#       'clone_url': 'https://github.com/ory/kratos.git',
#       'svn_url': 'https://github.com/ory/kratos',
#       'homepage': 'https://www.ory.sh/kratos/?utm_source=github&utm_medium=banner&utm_campaign=kratos',
#       'size': 82507,
#       'stargazers_count': 8411,
#       'watchers_count': 8411,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 751,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 250,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest',
#        'identity',
#        'identity-management',
#        'login',
#        'profile-management',
#        'registration',
#        'user',
#        'user-management',
#        'user-profile',
#        'user-profiles',
#        'users'],
#       'visibility': 'public',
#       'forks': 751,
#       'open_issues': 250,
#       'watchers': 8411,
#       'default_branch': 'master'}},
#     'base': {'label': 'ory:master',
#      'ref': 'master',
#      'sha': '523b93fd1fe8715d06aeedc2db0ac072dfcafb71',
#      'user': {'login': 'ory',
#       'id': 25334553,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ory',
#       'html_url': 'https://github.com/ory',
#       'followers_url': 'https://api.github.com/users/ory/followers',
#       'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ory/orgs',
#       'repos_url': 'https://api.github.com/users/ory/repos',
#       'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ory/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 135321861,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzUzMjE4NjE=',
#       'name': 'kratos',
#       'full_name': 'ory/kratos',
#       'private': False,
#       'owner': {'login': 'ory',
#        'id': 25334553,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ory',
#        'html_url': 'https://github.com/ory',
#        'followers_url': 'https://api.github.com/users/ory/followers',
#        'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ory/orgs',
#        'repos_url': 'https://api.github.com/users/ory/repos',
#        'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ory/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ory/kratos',
#       'description': 'Next-gen identity server (think Auth0, Okta, Firebase) with Ory-hardened authentication, MFA, FIDO2, TOTP, WebAuthn, profile management, identity schemas, social sign in, registration, account recovery, passwordless. Golang, headless, API-only - without templating or theming headaches. Available as a cloud service.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ory/kratos',
#       'forks_url': 'https://api.github.com/repos/ory/kratos/forks',
#       'keys_url': 'https://api.github.com/repos/ory/kratos/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ory/kratos/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ory/kratos/teams',
#       'hooks_url': 'https://api.github.com/repos/ory/kratos/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ory/kratos/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ory/kratos/events',
#       'assignees_url': 'https://api.github.com/repos/ory/kratos/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ory/kratos/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ory/kratos/tags',
#       'blobs_url': 'https://api.github.com/repos/ory/kratos/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ory/kratos/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ory/kratos/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ory/kratos/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ory/kratos/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ory/kratos/languages',
#       'stargazers_url': 'https://api.github.com/repos/ory/kratos/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ory/kratos/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ory/kratos/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ory/kratos/subscription',
#       'commits_url': 'https://api.github.com/repos/ory/kratos/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ory/kratos/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ory/kratos/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ory/kratos/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ory/kratos/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ory/kratos/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ory/kratos/merges',
#       'archive_url': 'https://api.github.com/repos/ory/kratos/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ory/kratos/downloads',
#       'issues_url': 'https://api.github.com/repos/ory/kratos/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ory/kratos/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ory/kratos/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ory/kratos/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ory/kratos/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ory/kratos/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ory/kratos/deployments',
#       'created_at': '2018-05-29T16:09:37Z',
#       'updated_at': '2023-04-17T11:36:21Z',
#       'pushed_at': '2023-04-17T14:46:49Z',
#       'git_url': 'git://github.com/ory/kratos.git',
#       'ssh_url': 'git@github.com:ory/kratos.git',
#       'clone_url': 'https://github.com/ory/kratos.git',
#       'svn_url': 'https://github.com/ory/kratos',
#       'homepage': 'https://www.ory.sh/kratos/?utm_source=github&utm_medium=banner&utm_campaign=kratos',
#       'size': 82507,
#       'stargazers_count': 8411,
#       'watchers_count': 8411,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 751,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 250,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest',
#        'identity',
#        'identity-management',
#        'login',
#        'profile-management',
#        'registration',
#        'user',
#        'user-management',
#        'user-profile',
#        'user-profiles',
#        'users'],
#       'visibility': 'public',
#       'forks': 751,
#       'open_issues': 250,
#       'watchers': 8411,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235'},
#      'html': {'href': 'https://github.com/ory/kratos/pull/3235'},
#      'issue': {'href': 'https://api.github.com/repos/ory/kratos/issues/3235'},
#      'comments': {'href': 'https://api.github.com/repos/ory/kratos/issues/3235/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ory/kratos/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ory/kratos/statuses/99248f3abcec54870a6aeca0c7497ed14ab90c86'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-04-17T16:03:39Z',
#   'org': {'id': 25334553,
#    'login': 'ory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?'}},
#  {'id': '28470051889',
#   'type': 'MemberEvent',
#   'actor': {'id': 117729152,
#    'login': 'Xernnn',
#    'display_login': 'Xernnn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Xernnn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117729152?'},
#   'repo': {'id': 621684127,
#    'name': 'Xernnn/Comics',
#    'url': 'https://api.github.com/repos/Xernnn/Comics'},
#   'payload': {'member': {'login': 'anminhtri',
#     'id': 100016217,
#     'node_id': 'U_kgDOBfYgWQ',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/100016217?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/anminhtri',
#     'html_url': 'https://github.com/anminhtri',
#     'followers_url': 'https://api.github.com/users/anminhtri/followers',
#     'following_url': 'https://api.github.com/users/anminhtri/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/anminhtri/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/anminhtri/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/anminhtri/subscriptions',
#     'organizations_url': 'https://api.github.com/users/anminhtri/orgs',
#     'repos_url': 'https://api.github.com/users/anminhtri/repos',
#     'events_url': 'https://api.github.com/users/anminhtri/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/anminhtri/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051831',
#   'type': 'PushEvent',
#   'actor': {'id': 13872904,
#    'login': 'KaushikRishabh',
#    'display_login': 'KaushikRishabh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KaushikRishabh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13872904?'},
#   'repo': {'id': 629100603,
#    'name': 'KaushikRishabh/react-html-to-rich-text',
#    'url': 'https://api.github.com/repos/KaushikRishabh/react-html-to-rich-text'},
#   'payload': {'repository_id': 629100603,
#    'push_id': 13328946642,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bf53d925f482b082e6d877d4a539bcf67a2184d0',
#    'before': '11f6fe909004445d8694eb5ad574ceddd27a2e9d',
#    'commits': [{'sha': 'bf53d925f482b082e6d877d4a539bcf67a2184d0',
#      'author': {'email': 'reachmeatrish@gmail.com', 'name': 'Rishabh Kaushik'},
#      'message': 'Initial commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/KaushikRishabh/react-html-to-rich-text/commits/bf53d925f482b082e6d877d4a539bcf67a2184d0'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051974',
#   'type': 'CreateEvent',
#   'actor': {'id': 119161971,
#    'login': 'ajeetdp',
#    'display_login': 'ajeetdp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ajeetdp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119161971?'},
#   'repo': {'id': 629100459,
#    'name': 'ajeetdp/cricketworld',
#    'url': 'https://api.github.com/repos/ajeetdp/cricketworld'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051859',
#   'type': 'PushEvent',
#   'actor': {'id': 34553908,
#    'login': 'dschibster',
#    'display_login': 'dschibster',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dschibster',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34553908?'},
#   'repo': {'id': 586995654,
#    'name': 'mind-labs/sf-dynamic-approvals',
#    'url': 'https://api.github.com/repos/mind-labs/sf-dynamic-approvals'},
#   'payload': {'repository_id': 586995654,
#    'push_id': 13328946664,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/poc-process-invocation-pfe',
#    'head': 'af4814add3d46448efe4e8f8fcf5df36c5cc2b72',
#    'before': '6208bc3769ffebf56c0591ec430cc9b340848f00',
#    'commits': [{'sha': 'af4814add3d46448efe4e8f8fcf5df36c5cc2b72',
#      'author': {'email': 'dschib@live.de', 'name': 'Dennis Grzyb'},
#      'message': 'PoC start: Length check of SOBject JSON and Approval Dispatcher Class',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mind-labs/sf-dynamic-approvals/commits/af4814add3d46448efe4e8f8fcf5df36c5cc2b72'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z',
#   'org': {'id': 122306330,
#    'login': 'mind-labs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mind-labs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122306330?'}},
#  {'id': '28470051900',
#   'type': 'CreateEvent',
#   'actor': {'id': 75875444,
#    'login': 'hitenanand97',
#    'display_login': 'hitenanand97',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hitenanand97',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75875444?'},
#   'repo': {'id': 629100613,
#    'name': 'hitenanand97/hitenanand97',
#    'url': 'https://api.github.com/repos/hitenanand97/hitenanand97'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051910',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 594169901,
#    'name': 'peter279k/cdc-data-mirror',
#    'url': 'https://api.github.com/repos/peter279k/cdc-data-mirror'},
#   'payload': {'repository_id': 594169901,
#    'push_id': 13328946716,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '10cbf88e2c024aed090e7c39a83dba458895bc5a',
#    'before': 'ffd5ea09a4ffd7f5a69de60b5de6f1532c30ebd2',
#    'commits': [{'sha': '10cbf88e2c024aed090e7c39a83dba458895bc5a',
#      'author': {'email': 'peter279k@gmail.com', 'name': 'peter279k'},
#      'message': 'Last Commit: Tue Apr 18 00:07:54 CST 2023(TW)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peter279k/cdc-data-mirror/commits/10cbf88e2c024aed090e7c39a83dba458895bc5a'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051935',
#   'type': 'PushEvent',
#   'actor': {'id': 76601914,
#    'login': 'fullfeeds',
#    'display_login': 'fullfeeds',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fullfeeds',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76601914?'},
#   'repo': {'id': 324450602,
#    'name': 'fullfeeds/feeds',
#    'url': 'https://api.github.com/repos/fullfeeds/feeds'},
#   'payload': {'repository_id': 324450602,
#    'push_id': 13328946705,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1bb4e9bd8add9ef31e5595400fcf04a1305028a0',
#    'before': '5f5a2527290a130306b5c46421fe1dbca648e6e5',
#    'commits': [{'sha': '1bb4e9bd8add9ef31e5595400fcf04a1305028a0',
#      'author': {'email': 'fullfeeds@localhost', 'name': 'Fullfeeds Daemon'},
#      'message': 'Update: 2023-04-17-16:07:53',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fullfeeds/feeds/commits/1bb4e9bd8add9ef31e5595400fcf04a1305028a0'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051855',
#   'type': 'PushEvent',
#   'actor': {'id': 129499031,
#    'login': 'Christoffel-T',
#    'display_login': 'Christoffel-T',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Christoffel-T',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/129499031?'},
#   'repo': {'id': 621725696,
#    'name': 'Christoffel-T/fiverr-pat-20230331',
#    'url': 'https://api.github.com/repos/Christoffel-T/fiverr-pat-20230331'},
#   'payload': {'repository_id': 621725696,
#    'push_id': 13328946676,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aad83dffa6912266d80b9ef9c56ac2f771f33b36',
#    'before': '07caebef9511086f8d3d3dc7f26a5c0e54064d16',
#    'commits': [{'sha': 'aad83dffa6912266d80b9ef9c56ac2f771f33b36',
#      'author': {'email': '129499031+Christoffel-T@users.noreply.github.com',
#       'name': 'Christoffel-T'},
#      'message': 'Replace file content',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Christoffel-T/fiverr-pat-20230331/commits/aad83dffa6912266d80b9ef9c56ac2f771f33b36'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051893',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 45748163,
#    'login': 'Averagess',
#    'display_login': 'Averagess',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Averagess',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45748163?'},
#   'repo': {'id': 592097254,
#    'name': 'Averagess/bitcollector-bot',
#    'url': 'https://api.github.com/repos/Averagess/bitcollector-bot'},
#   'payload': {'action': 'opened',
#    'number': 62,
#    'pull_request': {'url': 'https://api.github.com/repos/Averagess/bitcollector-bot/pulls/62',
#     'id': 1316944906,
#     'node_id': 'PR_kwDOI0qv5s5OfvwK',
#     'html_url': 'https://github.com/Averagess/bitcollector-bot/pull/62',
#     'diff_url': 'https://github.com/Averagess/bitcollector-bot/pull/62.diff',
#     'patch_url': 'https://github.com/Averagess/bitcollector-bot/pull/62.patch',
#     'issue_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/issues/62',
#     'number': 62,
#     'state': 'open',
#     'locked': False,
#     'title': 'Updated embed',
#     'user': {'login': 'Averagess',
#      'id': 45748163,
#      'node_id': 'MDQ6VXNlcjQ1NzQ4MTYz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/45748163?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Averagess',
#      'html_url': 'https://github.com/Averagess',
#      'followers_url': 'https://api.github.com/users/Averagess/followers',
#      'following_url': 'https://api.github.com/users/Averagess/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Averagess/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Averagess/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Averagess/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Averagess/orgs',
#      'repos_url': 'https://api.github.com/users/Averagess/repos',
#      'events_url': 'https://api.github.com/users/Averagess/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Averagess/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-04-17T16:07:54Z',
#     'updated_at': '2023-04-17T16:07:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/pulls/62/commits',
#     'review_comments_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/pulls/62/comments',
#     'review_comment_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/issues/62/comments',
#     'statuses_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/statuses/fc15363391635b624edec2ce7603f9a36fa11995',
#     'head': {'label': 'Averagess:dev',
#      'ref': 'dev',
#      'sha': 'fc15363391635b624edec2ce7603f9a36fa11995',
#      'user': {'login': 'Averagess',
#       'id': 45748163,
#       'node_id': 'MDQ6VXNlcjQ1NzQ4MTYz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45748163?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Averagess',
#       'html_url': 'https://github.com/Averagess',
#       'followers_url': 'https://api.github.com/users/Averagess/followers',
#       'following_url': 'https://api.github.com/users/Averagess/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Averagess/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Averagess/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Averagess/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Averagess/orgs',
#       'repos_url': 'https://api.github.com/users/Averagess/repos',
#       'events_url': 'https://api.github.com/users/Averagess/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Averagess/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 592097254,
#       'node_id': 'R_kgDOI0qv5g',
#       'name': 'bitcollector-bot',
#       'full_name': 'Averagess/bitcollector-bot',
#       'private': False,
#       'owner': {'login': 'Averagess',
#        'id': 45748163,
#        'node_id': 'MDQ6VXNlcjQ1NzQ4MTYz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/45748163?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Averagess',
#        'html_url': 'https://github.com/Averagess',
#        'followers_url': 'https://api.github.com/users/Averagess/followers',
#        'following_url': 'https://api.github.com/users/Averagess/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Averagess/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Averagess/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Averagess/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Averagess/orgs',
#        'repos_url': 'https://api.github.com/users/Averagess/repos',
#        'events_url': 'https://api.github.com/users/Averagess/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Averagess/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Averagess/bitcollector-bot',
#       'description': "Bit collector's bot, built with discord.js",
#       'fork': False,
#       'url': 'https://api.github.com/repos/Averagess/bitcollector-bot',
#       'forks_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/forks',
#       'keys_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/teams',
#       'hooks_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/events',
#       'assignees_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/tags',
#       'blobs_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/languages',
#       'stargazers_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/subscription',
#       'commits_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/merges',
#       'archive_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/downloads',
#       'issues_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Averagess/bitcollector-bot/deployments',
#       'created_at': '2023-01-22T22:29:33Z',
#       'updated_at': '2023-03-27T22:02:00Z',
#       'pushed_at': '2023-04-17T16:07:38Z',
#       'git_url': 'git://github.com/Averagess/bitcollector-bot.git',
#       'ssh_url': 'git@github.com:Averagess/bitcollector-bot.git',
#       'clone_url': 'https://github.com/Averagess/bitcollector-bot.git',
#       'svn_url': 'https://github.com/Averagess/bitcollector-bot',
#       'homepage': '',
#       'size': 1642,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Averagess:master',
#      'ref': 'master',
#      'sha': 'babfe7614deaa16c476d01f7abba13c08b28f0fc',
#      'user': {'login': 'Averagess',
#       'id': 45748163,
#       'node_id': 'MDQ6VXNlcjQ1NzQ4MTYz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45748163?v=4',
#       'gravatar_id': '',
# ...
#      'ref': 'master',
#      'sha': '523b93fd1fe8715d06aeedc2db0ac072dfcafb71',
#      'user': {'login': 'ory',
#       'id': 25334553,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ory',
#       'html_url': 'https://github.com/ory',
#       'followers_url': 'https://api.github.com/users/ory/followers',
#       'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ory/orgs',
#       'repos_url': 'https://api.github.com/users/ory/repos',
#       'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ory/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 135321861,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzUzMjE4NjE=',
#       'name': 'kratos',
#       'full_name': 'ory/kratos',
#       'private': False,
#       'owner': {'login': 'ory',
#        'id': 25334553,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1MzM0NTUz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ory',
#        'html_url': 'https://github.com/ory',
#        'followers_url': 'https://api.github.com/users/ory/followers',
#        'following_url': 'https://api.github.com/users/ory/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ory/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ory/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ory/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ory/orgs',
#        'repos_url': 'https://api.github.com/users/ory/repos',
#        'events_url': 'https://api.github.com/users/ory/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ory/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ory/kratos',
#       'description': 'Next-gen identity server (think Auth0, Okta, Firebase) with Ory-hardened authentication, MFA, FIDO2, TOTP, WebAuthn, profile management, identity schemas, social sign in, registration, account recovery, passwordless. Golang, headless, API-only - without templating or theming headaches. Available as a cloud service.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ory/kratos',
#       'forks_url': 'https://api.github.com/repos/ory/kratos/forks',
#       'keys_url': 'https://api.github.com/repos/ory/kratos/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ory/kratos/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ory/kratos/teams',
#       'hooks_url': 'https://api.github.com/repos/ory/kratos/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ory/kratos/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ory/kratos/events',
#       'assignees_url': 'https://api.github.com/repos/ory/kratos/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ory/kratos/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ory/kratos/tags',
#       'blobs_url': 'https://api.github.com/repos/ory/kratos/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ory/kratos/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ory/kratos/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ory/kratos/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ory/kratos/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ory/kratos/languages',
#       'stargazers_url': 'https://api.github.com/repos/ory/kratos/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ory/kratos/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ory/kratos/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ory/kratos/subscription',
#       'commits_url': 'https://api.github.com/repos/ory/kratos/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ory/kratos/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ory/kratos/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ory/kratos/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ory/kratos/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ory/kratos/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ory/kratos/merges',
#       'archive_url': 'https://api.github.com/repos/ory/kratos/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ory/kratos/downloads',
#       'issues_url': 'https://api.github.com/repos/ory/kratos/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ory/kratos/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ory/kratos/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ory/kratos/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ory/kratos/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ory/kratos/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ory/kratos/deployments',
#       'created_at': '2018-05-29T16:09:37Z',
#       'updated_at': '2023-04-17T11:36:21Z',
#       'pushed_at': '2023-04-17T14:46:49Z',
#       'git_url': 'git://github.com/ory/kratos.git',
#       'ssh_url': 'git@github.com:ory/kratos.git',
#       'clone_url': 'https://github.com/ory/kratos.git',
#       'svn_url': 'https://github.com/ory/kratos',
#       'homepage': 'https://www.ory.sh/kratos/?utm_source=github&utm_medium=banner&utm_campaign=kratos',
#       'size': 82507,
#       'stargazers_count': 8411,
#       'watchers_count': 8411,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 751,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 250,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest',
#        'identity',
#        'identity-management',
#        'login',
#        'profile-management',
#        'registration',
#        'user',
#        'user-management',
#        'user-profile',
#        'user-profiles',
#        'users'],
#       'visibility': 'public',
#       'forks': 751,
#       'open_issues': 250,
#       'watchers': 8411,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235'},
#      'html': {'href': 'https://github.com/ory/kratos/pull/3235'},
#      'issue': {'href': 'https://api.github.com/repos/ory/kratos/issues/3235'},
#      'comments': {'href': 'https://api.github.com/repos/ory/kratos/issues/3235/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ory/kratos/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ory/kratos/pulls/3235/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ory/kratos/statuses/99248f3abcec54870a6aeca0c7497ed14ab90c86'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-04-17T15:58:15Z',
#   'org': {'id': 25334553,
#    'login': 'ory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25334553?'}},
#  {'id': '28470051755',
#   'type': 'PushEvent',
#   'actor': {'id': 83090077,
#    'login': 'Boygame666',
#    'display_login': 'Boygame666',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Boygame666',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83090077?'},
#   'repo': {'id': 598512250,
#    'name': 'Boygame666/GoodGreen',
#    'url': 'https://api.github.com/repos/Boygame666/GoodGreen'},
#   'payload': {'repository_id': 598512250,
#    'push_id': 13328946620,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bea6622ac1e2950600915ac9735ec2089b73be23',
#    'before': '15fb750d97423bdf0df9bd6ab1a11684e358a28a',
#    'commits': [{'sha': 'bea6622ac1e2950600915ac9735ec2089b73be23',
#      'author': {'email': '83090077+Boygame666@users.noreply.github.com',
#       'name': 'Boygame666'},
#      'message': 'default',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Boygame666/GoodGreen/commits/bea6622ac1e2950600915ac9735ec2089b73be23'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051805',
#   'type': 'WatchEvent',
#   'actor': {'id': 70440982,
#    'login': 'AmirJlr',
#    'display_login': 'AmirJlr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AmirJlr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70440982?'},
#   'repo': {'id': 327423125,
#    'name': 'LisaHJung/Beginners-Crash-Course-to-Elastic-Stack-Series-Table-of-Contents',
#    'url': 'https://api.github.com/repos/LisaHJung/Beginners-Crash-Course-to-Elastic-Stack-Series-Table-of-Contents'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051795',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 198908126,
#    'name': 'renovate-bot/common-protos-ruby',
#    'url': 'https://api.github.com/repos/renovate-bot/common-protos-ruby'},
#   'payload': {'repository_id': 198908126,
#    'push_id': 13328946661,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': '59cf6300ca0f0ade88de0f75e2aac50c75a10a56',
#    'before': '59cf6300ca0f0ade88de0f75e2aac50c75a10a56',
#    'commits': []},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051745',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 255181569,
#    'name': 'libbpf/libbpf-rs',
#    'url': 'https://api.github.com/repos/libbpf/libbpf-rs'},
#   'payload': {'ref': 'dependabot/cargo/serde_json-1.0.96',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z',
#   'org': {'id': 44008517,
#    'login': 'libbpf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/libbpf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44008517?'}},
#  {'id': '28470051734',
#   'type': 'PushEvent',
#   'actor': {'id': 114741565,
#    'login': 'LSB616',
#    'display_login': 'LSB616',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LSB616',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114741565?'},
#   'repo': {'id': 629056782,
#    'name': 'LSB616/music_app',
#    'url': 'https://api.github.com/repos/LSB616/music_app'},
#   'payload': {'repository_id': 629056782,
#    'push_id': 13328946608,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6099554edee4f4ab0a75b86413b8563c887ed314',
#    'before': '7c595146895d40241973456e47ddc37655ea7d0f',
#    'commits': [{'sha': '6099554edee4f4ab0a75b86413b8563c887ed314',
#      'author': {'email': '114741565+LSB616@users.noreply.github.com',
#       'name': 'Lewis'},
#      'message': 'Delete README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LSB616/music_app/commits/6099554edee4f4ab0a75b86413b8563c887ed314'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z'},
#  {'id': '28470051747',
#   'type': 'PushEvent',
#   'actor': {'id': 49153372,
#    'login': 'nickchapman-da',
#    'display_login': 'nickchapman-da',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nickchapman-da',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49153372?'},
#   'repo': {'id': 178222328,
#    'name': 'digital-asset/daml',
#    'url': 'https://api.github.com/repos/digital-asset/daml'},
#   'payload': {'repository_id': 178222328,
#    'push_id': 13328946537,
#    'size': 6,
#    'distinct_size': 1,
#    'ref': 'refs/heads/nick/kill-ptx-gain-restrict-authority',
#    'head': 'e276cbf7fe7eec7efeb91499ed32139e2e426a33',
#    'before': 'a0ee421f29909206026b76c4078a26e5e647d45b',
#    'commits': [{'sha': '6444f1ef87dc78405adc1c45f3c3e5f2d86466db',
#      'author': {'email': 'gary.verhaegen@digitalasset.com',
#       'name': 'Gary Verhaegen'},
#      'message': "review release documentation (#16619)\n\nI think I've made things clearer, but please let me know either way.",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/6444f1ef87dc78405adc1c45f3c3e5f2d86466db'},
#     {'sha': '32ac68419ce918af062fc69a8719709092c8c766',
#      'author': {'email': '36771401+azure-pipelines[bot]@users.noreply.github.com',
#       'name': 'azure-pipelines[bot]'},
#      'message': 'bump canton to 20230414 (#16699)\n\nCHANGELOG_BEGIN\r\nCHANGELOG_END\r\n\r\nCo-authored-by: Azure Pipelines Daml Build <support@digitalasset.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/32ac68419ce918af062fc69a8719709092c8c766'},
#     {'sha': 'f8050f1f181186424e8e7dc45f5d34129c17ba6e',
#      'author': {'email': 'gary.verhaegen@digitalasset.com',
#       'name': 'Gary Verhaegen'},
#      'message': 'Add license file (#16697)\n\nSee [DAML-358] for details.\r\n\r\n[DAML-358]: https://digitalasset.atlassian.net/browse/DAML-358',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/f8050f1f181186424e8e7dc45f5d34129c17ba6e'},
#     {'sha': 'e1a96bc54356fdb8ec8e6a964681b231b6c0b8cf',
#      'author': {'email': '36771401+azure-pipelines[bot]@users.noreply.github.com',
#       'name': 'azure-pipelines[bot]'},
#      'message': 'update NOTICES file (#16701)\n\nCHANGELOG_BEGIN\r\nCHANGELOG_END\r\n\r\nCo-authored-by: Azure Pipelines Daml Build <support@digitalasset.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/e1a96bc54356fdb8ec8e6a964681b231b6c0b8cf'},
#     {'sha': 'ac68bdf416b3f8addeb93deb68cf7974706c4ea2',
#      'author': {'email': '49153372+nickchapman-da@users.noreply.github.com',
#       'name': 'nickchapman-da'},
#      'message': '[engine] kill Daml withAuthority / LF WITH_AUTHORITY (#16548)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/ac68bdf416b3f8addeb93deb68cf7974706c4ea2'},
#     {'sha': 'e276cbf7fe7eec7efeb91499ed32139e2e426a33',
#      'author': {'email': 'nick.chapman@digitalasset.com',
#       'name': 'Nick Chapman'},
#      'message': 'kill with fire',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/digital-asset/daml/commits/e276cbf7fe7eec7efeb91499ed32139e2e426a33'}]},
#   'public': True,
#   'created_at': '2023-04-17T16:07:55Z',
#   'org': {'id': 46327217,
#    'login': 'digital-asset',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/digital-asset',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46327217?'}}]

# %%
# How many events are we looking at?
len(github_response)
# Out:
# 30

# %%
# What are the keys in the first event?
github_response[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %%
# We can see that 'repo' is another subdictionary.
# What are the keys in the 'repo' subdictionary?
github_response[0]['repo'].keys()
# Out:
# dict_keys(['id', 'name', 'url'])

# %%
# What's the value for the key 'name' in 'repo'?
github_response[0]['repo']['name']
# Out:
# 'ory/kratos'

# %% [markdown]
# #### Transforming a JSON into a DataFrame

# %% [markdown]
# ##### Option 1: pd.DataFrame()

# %%
# Turn it into a pandas DataFrame.
pd.DataFrame(github_response)
# Out:
#              id                           type  \
# 0   28470051881  PullRequestReviewCommentEvent
# 1   28470051889                    MemberEvent
# 2   28470051831                      PushEvent
# 3   28470051974                    CreateEvent
# 4   28470051859                      PushEvent
# 5   28470051900                    CreateEvent
# 6   28470051910                      PushEvent
# 7   28470051935                      PushEvent
# 8   28470051855                      PushEvent
# 9   28470051893               PullRequestEvent
# 10  28470051761                      PushEvent
# 11  28470051845              IssueCommentEvent
# 12  28470051726                      PushEvent
# 13  28470051815                      PushEvent
# 14  28470051838                      PushEvent
# 15  28470051779                      PushEvent
# 16  28470051715                    DeleteEvent
# 17  28470051778             CommitCommentEvent
# 18  28470051763                      PushEvent
# 19  28470051809                      PushEvent
# 20  28470051832                    PublicEvent
# 21  28470051792  PullRequestReviewCommentEvent
# 22  28470051812              IssueCommentEvent
# 23  28470051800  PullRequestReviewCommentEvent
# 24  28470051755                      PushEvent
# 25  28470051805                     WatchEvent
# 26  28470051795                      PushEvent
# 27  28470051745                    DeleteEvent
# 28  28470051734                      PushEvent
# 29  28470051747                      PushEvent
#
#                                                 actor  \
# 0   {'id': 18215579, 'login': 'CaptainStandby', 'd...
# 1   {'id': 117729152, 'login': 'Xernnn', 'display_...
# 2   {'id': 13872904, 'login': 'KaushikRishabh', 'd...
# 3   {'id': 119161971, 'login': 'ajeetdp', 'display...
# 4   {'id': 34553908, 'login': 'dschibster', 'displ...
# 5   {'id': 75875444, 'login': 'hitenanand97', 'dis...
# 6   {'id': 41898282, 'login': 'github-actions[bot]...
# 7   {'id': 76601914, 'login': 'fullfeeds', 'displa...
# 8   {'id': 129499031, 'login': 'Christoffel-T', 'd...
# 9   {'id': 45748163, 'login': 'Averagess', 'displa...
# 10  {'id': 102661435, 'login': 'egorps4', 'display...
# 11  {'id': 101540606, 'login': 'oss-fuzz-robot', '...
# 12  {'id': 41898282, 'login': 'github-actions[bot]...
# 13  {'id': 41898282, 'login': 'github-actions[bot]...
# 14  {'id': 103143237, 'login': 'AidanCox122', 'dis...
# 15  {'id': 10732005, 'login': 'cston', 'display_lo...
# 16  {'id': 55348, 'login': 'akosma', 'display_logi...
# 17  {'id': 35613825, 'login': 'vercel[bot]', 'disp...
# 18  {'id': 123810865, 'login': 'DarkOffical', 'dis...
# 19  {'id': 78225772, 'login': 'hellblazer7', 'disp...
# 20  {'id': 112066503, 'login': 'GungIndi', 'displa...
# 21  {'id': 103955289, 'login': 'tbjump', 'display_...
# 22  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 23  {'id': 18215579, 'login': 'CaptainStandby', 'd...
# 24  {'id': 83090077, 'login': 'Boygame666', 'displ...
# 25  {'id': 70440982, 'login': 'AmirJlr', 'display_...
# 26  {'id': 25180681, 'login': 'renovate-bot', 'dis...
# 27  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 28  {'id': 114741565, 'login': 'LSB616', 'display_...
# 29  {'id': 49153372, 'login': 'nickchapman-da', 'd...
#
#                                                  repo  \
# 0   {'id': 135321861, 'name': 'ory/kratos', 'url':...
# 1   {'id': 621684127, 'name': 'Xernnn/Comics', 'ur...
# 2   {'id': 629100603, 'name': 'KaushikRishabh/reac...
# 3   {'id': 629100459, 'name': 'ajeetdp/cricketworl...
# 4   {'id': 586995654, 'name': 'mind-labs/sf-dynami...
# 5   {'id': 629100613, 'name': 'hitenanand97/hitena...
# 6   {'id': 594169901, 'name': 'peter279k/cdc-data-...
# 7   {'id': 324450602, 'name': 'fullfeeds/feeds', '...
# 8   {'id': 621725696, 'name': 'Christoffel-T/fiver...
# 9   {'id': 592097254, 'name': 'Averagess/bitcollec...
# 10  {'id': 625585725, 'name': 'egorps4/XBOX', 'url...
# 11  {'id': 32873313, 'name': 'systemd/systemd', 'u...
# 12  {'id': 464798908, 'name': 'prakashtv007/UTLive...
# 13  {'id': 540678304, 'name': 'kentayamada-dev/ken...
# 14  {'id': 572727022, 'name': 'AidanCox122/blues-m...
# 15  {'id': 30556803, 'name': 'cston/roslyn', 'url'...
# 16  {'id': 225376739, 'name': 'vshn/nginx', 'url':...
# 17  {'id': 591016699, 'name': 'igornevesg/DR-Paulo...
# 18  {'id': 629042189, 'name': 'DarkOffical/Elsa', ...
# 19  {'id': 628372118, 'name': 'hellblazer7/Moody-M...
# 20  {'id': 625825598, 'name': 'GungIndi/Simple-Onl...
# 21  {'id': 282684311, 'name': 'wormhole-foundation...
# 22  {'id': 220356927, 'name': 'spectrocloud/cluste...
# 23  {'id': 135321861, 'name': 'ory/kratos', 'url':...
# 24  {'id': 598512250, 'name': 'Boygame666/GoodGree...
# 25  {'id': 327423125, 'name': 'LisaHJung/Beginners...
# 26  {'id': 198908126, 'name': 'renovate-bot/common...
# 27  {'id': 255181569, 'name': 'libbpf/libbpf-rs', ...
# 28  {'id': 629056782, 'name': 'LSB616/music_app', ...
# 29  {'id': 178222328, 'name': 'digital-asset/daml'...
#
#                                               payload  public  \
# 0   {'action': 'created', 'comment': {'url': 'http...    True
# 1   {'member': {'login': 'anminhtri', 'id': 100016...    True
# 2   {'repository_id': 629100603, 'push_id': 133289...    True
# 3   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 4   {'repository_id': 586995654, 'push_id': 133289...    True
# 5   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 6   {'repository_id': 594169901, 'push_id': 133289...    True
# 7   {'repository_id': 324450602, 'push_id': 133289...    True
# 8   {'repository_id': 621725696, 'push_id': 133289...    True
# 9   {'action': 'opened', 'number': 62, 'pull_reque...    True
# 10  {'repository_id': 625585725, 'push_id': 133289...    True
# 11  {'action': 'created', 'issue': {'url': 'https:...    True
# 12  {'repository_id': 464798908, 'push_id': 133289...    True
# 13  {'repository_id': 540678304, 'push_id': 133289...    True
# 14  {'repository_id': 572727022, 'push_id': 133289...    True
# 15  {'repository_id': 30556803, 'push_id': 1332894...    True
# 16  {'ref': 'renovate/docker-login-action-digest',...    True
# 17  {'comment': {'url': 'https://api.github.com/re...    True
# 18  {'repository_id': 629042189, 'push_id': 133289...    True
# 19  {'repository_id': 628372118, 'push_id': 133289...    True
# 20                                                 {}    True
# 21  {'action': 'created', 'comment': {'url': 'http...    True
# 22  {'action': 'created', 'issue': {'url': 'https:...    True
# 23  {'action': 'created', 'comment': {'url': 'http...    True
# 24  {'repository_id': 598512250, 'push_id': 133289...    True
# 25                              {'action': 'started'}    True
# 26  {'repository_id': 198908126, 'push_id': 133289...    True
# 27  {'ref': 'dependabot/cargo/serde_json-1.0.96', ...    True
# 28  {'repository_id': 629056782, 'push_id': 133289...    True
# 29  {'repository_id': 178222328, 'push_id': 133289...    True
#
#               created_at                                                org
# 0   2023-04-17T16:03:39Z  {'id': 25334553, 'login': 'ory', 'gravatar_id'...
# 1   2023-04-17T16:07:55Z                                                NaN
# 2   2023-04-17T16:07:55Z                                                NaN
# 3   2023-04-17T16:07:55Z                                                NaN
# 4   2023-04-17T16:07:55Z  {'id': 122306330, 'login': 'mind-labs', 'grava...
# 5   2023-04-17T16:07:55Z                                                NaN
# 6   2023-04-17T16:07:55Z                                                NaN
# 7   2023-04-17T16:07:55Z                                                NaN
# 8   2023-04-17T16:07:55Z                                                NaN
# 9   2023-04-17T16:07:55Z                                                NaN
# 10  2023-04-17T16:07:55Z                                                NaN
# 11  2023-04-17T16:07:55Z  {'id': 1918868, 'login': 'systemd', 'gravatar_...
# 12  2023-04-17T16:07:55Z                                                NaN
# 13  2023-04-17T16:07:55Z                                                NaN
# 14  2023-04-17T16:07:55Z                                                NaN
# 15  2023-04-17T16:07:55Z                                                NaN
# 16  2023-04-17T16:07:55Z  {'id': 9532446, 'login': 'vshn', 'gravatar_id'...
# 17  2023-04-17T16:07:54Z                                                NaN
# 18  2023-04-17T16:07:55Z                                                NaN
# 19  2023-04-17T16:07:55Z                                                NaN
# 20  2023-04-17T16:07:55Z                                                NaN
# 21  2023-04-17T16:07:54Z  {'id': 110117883, 'login': 'wormhole-foundatio...
# 22  2023-04-17T16:07:55Z  {'id': 36211249, 'login': 'spectrocloud', 'gra...
# 23  2023-04-17T15:58:15Z  {'id': 25334553, 'login': 'ory', 'gravatar_id'...
# 24  2023-04-17T16:07:55Z                                                NaN
# 25  2023-04-17T16:07:55Z                                                NaN
# 26  2023-04-17T16:07:55Z                                                NaN
# 27  2023-04-17T16:07:55Z  {'id': 44008517, 'login': 'libbpf', 'gravatar_...
# 28  2023-04-17T16:07:55Z                                                NaN
# 29  2023-04-17T16:07:55Z  {'id': 46327217, 'login': 'digital-asset', 'gr...

# %% [markdown]
# ##### Option 2: pd.json_normalize()
# You may notice above that many columns still contain dictionaries as values. We can correct this using json_normalize().
#
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
pd.json_normalize(github_response)
# Out:
#              id                           type  public            created_at  \
# 0   28470051881  PullRequestReviewCommentEvent    True  2023-04-17T16:03:39Z
# 1   28470051889                    MemberEvent    True  2023-04-17T16:07:55Z
# 2   28470051831                      PushEvent    True  2023-04-17T16:07:55Z
# 3   28470051974                    CreateEvent    True  2023-04-17T16:07:55Z
# 4   28470051859                      PushEvent    True  2023-04-17T16:07:55Z
# 5   28470051900                    CreateEvent    True  2023-04-17T16:07:55Z
# 6   28470051910                      PushEvent    True  2023-04-17T16:07:55Z
# 7   28470051935                      PushEvent    True  2023-04-17T16:07:55Z
# 8   28470051855                      PushEvent    True  2023-04-17T16:07:55Z
# 9   28470051893               PullRequestEvent    True  2023-04-17T16:07:55Z
# 10  28470051761                      PushEvent    True  2023-04-17T16:07:55Z
# 11  28470051845              IssueCommentEvent    True  2023-04-17T16:07:55Z
# 12  28470051726                      PushEvent    True  2023-04-17T16:07:55Z
# 13  28470051815                      PushEvent    True  2023-04-17T16:07:55Z
# 14  28470051838                      PushEvent    True  2023-04-17T16:07:55Z
# 15  28470051779                      PushEvent    True  2023-04-17T16:07:55Z
# 16  28470051715                    DeleteEvent    True  2023-04-17T16:07:55Z
# 17  28470051778             CommitCommentEvent    True  2023-04-17T16:07:54Z
# 18  28470051763                      PushEvent    True  2023-04-17T16:07:55Z
# 19  28470051809                      PushEvent    True  2023-04-17T16:07:55Z
# 20  28470051832                    PublicEvent    True  2023-04-17T16:07:55Z
# 21  28470051792  PullRequestReviewCommentEvent    True  2023-04-17T16:07:54Z
# 22  28470051812              IssueCommentEvent    True  2023-04-17T16:07:55Z
# 23  28470051800  PullRequestReviewCommentEvent    True  2023-04-17T15:58:15Z
# 24  28470051755                      PushEvent    True  2023-04-17T16:07:55Z
# 25  28470051805                     WatchEvent    True  2023-04-17T16:07:55Z
# 26  28470051795                      PushEvent    True  2023-04-17T16:07:55Z
# 27  28470051745                    DeleteEvent    True  2023-04-17T16:07:55Z
# 28  28470051734                      PushEvent    True  2023-04-17T16:07:55Z
# 29  28470051747                      PushEvent    True  2023-04-17T16:07:55Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0    18215579       CaptainStandby      CaptainStandby
# 1   117729152               Xernnn              Xernnn
# 2    13872904       KaushikRishabh      KaushikRishabh
# 3   119161971              ajeetdp             ajeetdp
# 4    34553908           dschibster          dschibster
# 5    75875444         hitenanand97        hitenanand97
# 6    41898282  github-actions[bot]      github-actions
# 7    76601914            fullfeeds           fullfeeds
# 8   129499031        Christoffel-T       Christoffel-T
# 9    45748163            Averagess           Averagess
# 10  102661435              egorps4             egorps4
# 11  101540606       oss-fuzz-robot      oss-fuzz-robot
# 12   41898282  github-actions[bot]      github-actions
# 13   41898282  github-actions[bot]      github-actions
# 14  103143237          AidanCox122         AidanCox122
# 15   10732005                cston               cston
# 16      55348               akosma              akosma
# 17   35613825          vercel[bot]              vercel
# 18  123810865          DarkOffical         DarkOffical
# 19   78225772          hellblazer7         hellblazer7
# 20  112066503             GungIndi            GungIndi
# 21  103955289               tbjump              tbjump
# 22   49699333      dependabot[bot]          dependabot
# 23   18215579       CaptainStandby      CaptainStandby
# 24   83090077           Boygame666          Boygame666
# 25   70440982              AmirJlr             AmirJlr
# 26   25180681         renovate-bot        renovate-bot
# 27   49699333      dependabot[bot]          dependabot
# 28  114741565               LSB616              LSB616
# 29   49153372       nickchapman-da      nickchapman-da
#
#                                            actor.url  \
# 0        https://api.github.com/users/CaptainStandby
# 1                https://api.github.com/users/Xernnn
# 2        https://api.github.com/users/KaushikRishabh
# 3               https://api.github.com/users/ajeetdp
# 4            https://api.github.com/users/dschibster
# 5          https://api.github.com/users/hitenanand97
# 6   https://api.github.com/users/github-actions[bot]
# 7             https://api.github.com/users/fullfeeds
# 8         https://api.github.com/users/Christoffel-T
# 9             https://api.github.com/users/Averagess
# 10              https://api.github.com/users/egorps4
# 11       https://api.github.com/users/oss-fuzz-robot
# 12  https://api.github.com/users/github-actions[bot]
# 13  https://api.github.com/users/github-actions[bot]
# 14          https://api.github.com/users/AidanCox122
# 15                https://api.github.com/users/cston
# 16               https://api.github.com/users/akosma
# 17          https://api.github.com/users/vercel[bot]
# 18          https://api.github.com/users/DarkOffical
# 19          https://api.github.com/users/hellblazer7
# 20             https://api.github.com/users/GungIndi
# 21               https://api.github.com/users/tbjump
# 22      https://api.github.com/users/dependabot[bot]
# 23       https://api.github.com/users/CaptainStandby
# 24           https://api.github.com/users/Boygame666
# 25              https://api.github.com/users/AmirJlr
# 26         https://api.github.com/users/renovate-bot
# 27      https://api.github.com/users/dependabot[bot]
# 28               https://api.github.com/users/LSB616
# 29       https://api.github.com/users/nickchapman-da
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/18215579?  ...
# 1   https://avatars.githubusercontent.com/u/117729...  ...
# 2   https://avatars.githubusercontent.com/u/13872904?  ...
# 3   https://avatars.githubusercontent.com/u/119161...  ...
# 4   https://avatars.githubusercontent.com/u/34553908?  ...
# 5   https://avatars.githubusercontent.com/u/75875444?  ...
# 6   https://avatars.githubusercontent.com/u/41898282?  ...
# 7   https://avatars.githubusercontent.com/u/76601914?  ...
# 8   https://avatars.githubusercontent.com/u/129499...  ...
# 9   https://avatars.githubusercontent.com/u/45748163?  ...
# 10  https://avatars.githubusercontent.com/u/102661...  ...
# 11  https://avatars.githubusercontent.com/u/101540...  ...
# 12  https://avatars.githubusercontent.com/u/41898282?  ...
# 13  https://avatars.githubusercontent.com/u/41898282?  ...
# 14  https://avatars.githubusercontent.com/u/103143...  ...
# 15  https://avatars.githubusercontent.com/u/10732005?  ...
# 16     https://avatars.githubusercontent.com/u/55348?  ...
# 17  https://avatars.githubusercontent.com/u/35613825?  ...
# 18  https://avatars.githubusercontent.com/u/123810...  ...
# 19  https://avatars.githubusercontent.com/u/78225772?  ...
# 20  https://avatars.githubusercontent.com/u/112066...  ...
# 21  https://avatars.githubusercontent.com/u/103955...  ...
# 22  https://avatars.githubusercontent.com/u/49699333?  ...
# 23  https://avatars.githubusercontent.com/u/18215579?  ...
# 24  https://avatars.githubusercontent.com/u/83090077?  ...
# 25  https://avatars.githubusercontent.com/u/70440982?  ...
# 26  https://avatars.githubusercontent.com/u/25180681?  ...
# 27  https://avatars.githubusercontent.com/u/49699333?  ...
# 28  https://avatars.githubusercontent.com/u/114741...  ...
# 29  https://avatars.githubusercontent.com/u/49153372?  ...
#
#     payload.issue.state_reason  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
#
#                             payload.comment.issue_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://api.github.com/repos/systemd/systemd/i...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/repos/spectrocloud/clus...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.comment.performed_via_github_app payload.comment.in_reply_to_id  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
# 5                                       NaN                            NaN
# 6                                       NaN                            NaN
# 7                                       NaN                            NaN
# 8                                       NaN                            NaN
# 9                                       NaN                            NaN
# 10                                      NaN                            NaN
# 11                                      NaN                            NaN
# 12                                      NaN                            NaN
# 13                                      NaN                            NaN
# 14                                      NaN                            NaN
# 15                                      NaN                            NaN
# 16                                      NaN                            NaN
# 17                                      NaN                            NaN
# 18                                      NaN                            NaN
# 19                                      NaN                            NaN
# 20                                      NaN                            NaN
# 21                                      NaN                   1.165961e+09
# 22                                      NaN                            NaN
# 23                                      NaN                            NaN
# 24                                      NaN                            NaN
# 25                                      NaN                            NaN
# 26                                      NaN                            NaN
# 27                                      NaN                            NaN
# 28                                      NaN                            NaN
# 29                                      NaN                            NaN
#
#    payload.issue.draft                     payload.issue.pull_request.url  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9                  NaN                                                NaN
# 10                 NaN                                                NaN
# 11                 NaN                                                NaN
# 12                 NaN                                                NaN
# 13                 NaN                                                NaN
# 14                 NaN                                                NaN
# 15                 NaN                                                NaN
# 16                 NaN                                                NaN
# 17                 NaN                                                NaN
# 18                 NaN                                                NaN
# 19                 NaN                                                NaN
# 20                 NaN                                                NaN
# 21                 NaN                                                NaN
# 22               False  https://api.github.com/repos/spectrocloud/clus...
# 23                 NaN                                                NaN
# 24                 NaN                                                NaN
# 25                 NaN                                                NaN
# 26                 NaN                                                NaN
# 27                 NaN                                                NaN
# 28                 NaN                                                NaN
# 29                 NaN                                                NaN
#
#                   payload.issue.pull_request.html_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://github.com/spectrocloud/cluster-api-pr...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                   payload.issue.pull_request.diff_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://github.com/spectrocloud/cluster-api-pr...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                  payload.issue.pull_request.patch_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://github.com/spectrocloud/cluster-api-pr...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.issue.pull_request.merged_at
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
#
# [30 rows x 497 columns]

# %% [markdown]
# #### Selecting only certain values by iterating with a for loop
#
# If we only want to select certain parts of the JSON:
# - Option 1: make a DataFrame and drop the rest.
# - Option 2: Use a for loop to extract only the required information.
#
# https://www.w3schools.com/python/python_for_loops.asp
#
# https://www.w3schools.com/python/ref_func_range.asp

# %%
# login - first value
github_response[0]['actor']['login']
# Out:
# 'CaptainStandby'

# %%
# repo - first value
github_response[0]['repo']['name']
# Out:
# 'ory/kratos'

# %%
# event_type - first value
github_response[0]['type']
# Out:
# 'PullRequestReviewCommentEvent'

# %%
# Empty lists that the loop will fill with values.
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    # add the ith login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the ith repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the ith event type to the event_type list
    event_type.append(github_response[i]['type'])

# %%
# Let's have a look at the login list.
login
# Out:
# ['CaptainStandby',
#  'Xernnn',
#  'KaushikRishabh',
#  'ajeetdp',
#  'dschibster',
#  'hitenanand97',
#  'github-actions[bot]',
#  'fullfeeds',
#  'Christoffel-T',
#  'Averagess',
#  'egorps4',
#  'oss-fuzz-robot',
#  'github-actions[bot]',
#  'github-actions[bot]',
#  'AidanCox122',
#  'cston',
#  'akosma',
#  'vercel[bot]',
#  'DarkOffical',
#  'hellblazer7',
#  'GungIndi',
#  'tbjump',
#  'dependabot[bot]',
#  'CaptainStandby',
#  'Boygame666',
#  'AmirJlr',
#  'renovate-bot',
#  'dependabot[bot]',
#  'LSB616',
#  'nickchapman-da']

# %%
# Let's have a look at the repo list.
repo
# Out:
# ['ory/kratos',
#  'Xernnn/Comics',
#  'KaushikRishabh/react-html-to-rich-text',
#  'ajeetdp/cricketworld',
#  'mind-labs/sf-dynamic-approvals',
#  'hitenanand97/hitenanand97',
#  'peter279k/cdc-data-mirror',
#  'fullfeeds/feeds',
#  'Christoffel-T/fiverr-pat-20230331',
#  'Averagess/bitcollector-bot',
#  'egorps4/XBOX',
#  'systemd/systemd',
#  'prakashtv007/UTLive2',
#  'kentayamada-dev/kentayamada-dev',
#  'AidanCox122/blues-makos',
#  'cston/roslyn',
#  'vshn/nginx',
#  'igornevesg/DR-Paulo',
#  'DarkOffical/Elsa',
#  'hellblazer7/Moody-Much',
#  'GungIndi/Simple-Online-Restaurant',
#  'wormhole-foundation/wormhole',
#  'spectrocloud/cluster-api-provider-aws',
#  'ory/kratos',
#  'Boygame666/GoodGreen',
#  'LisaHJung/Beginners-Crash-Course-to-Elastic-Stack-Series-Table-of-Contents',
#  'renovate-bot/common-protos-ruby',
#  'libbpf/libbpf-rs',
#  'LSB616/music_app',
#  'digital-asset/daml']

# %%
# Let's have a look at the event_type list.
event_type
# Out:
# ['PullRequestReviewCommentEvent',
#  'MemberEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'DeleteEvent',
#  'CommitCommentEvent',
#  'PushEvent',
#  'PushEvent',
#  'PublicEvent',
#  'PullRequestReviewCommentEvent',
#  'IssueCommentEvent',
#  'PullRequestReviewCommentEvent',
#  'PushEvent',
#  'WatchEvent',
#  'PushEvent',
#  'DeleteEvent',
#  'PushEvent',
#  'PushEvent']

# %% [markdown]
# ### International Space Station API - just another cool API
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1681747997,
#  'iss_position': {'latitude': '31.1766', 'longitude': '-29.0851'}}

# %% [markdown]
# ## Spotipy

# %% [markdown]
# Now that you know all about APIs, let's use that knowledge on something even more fun.
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into a Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentication
#
# With most APIs we need to autheticate ourself. This is often done with a username and a password. You will likely use a different username and password for most APIs, so make sure you're using a password manager, or keep everything written down somewhere safe.
#
# If ever you'd like more information about spotipy: [here are the docs](https://spotipy.readthedocs.io/en/2.19.0/).

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    #client_id="82d10cbeab244ba885a29af43becd014",
    #client_secret="b23ecbf78eb743b38161dae226870f4c"))

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="e5663f97f8484147b4e34ffc56894d91", # 
    client_secret="f770102854264b40b26c8cf54022ab3b")) #

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This method allows you to find songs using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
# Search for 'Lady Gaga', restricted to the first 10 results.

results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
# Only one key makes it seem like there'll be many subdictionaries, let's delve deeper.
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
# You can play the track by pasting the url in your browser.

# We can explore further by adding keys one after the other.

results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Poker Face'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: note the square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features contained in the search results:

# %%
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-tracks
# The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.

results["tracks"]["items"][0]["popularity"]
# Out:
# 78

# %% [markdown]
# This is how Spotify identifies individual songs: with a Uniform Resource Identifier  or `uri`. (The `id` and the `url` are also ways to identify each song uniquely).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5R8dQOPq8haW94K7mgERlO'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chili Peppers and store the `uri` of the songs and their names.

# %%
# Send request and store the response.
red_hot = sp.search(q="Red Hot Chili Peppers", limit=10)

# Initialize empty lists that we will fill with information from our loop.
list_of_uri = []
list_of_song_names = []

# Iterate through the "items" (the songs),
# and append the "uri" and the "name" to the lists we created.
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# Print results.
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:0uppYCG86ajpV2hSR3dJJ0', 'spotify:track:64BbK9SFKH2jk86U3dGj2P', 'spotify:track:1G391cbiT3v3Cywg8T7DM1', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:10Nmj3JCNoMeBQ87uw5j8k', 'spotify:track:1ndGB6rvxKYN9seCYO1dTF', 'spotify:track:1f2V8U1BiWaC9aJWmpOARe']
#
#
# ['Under the Bridge', 'Give It Away', 'Otherside', 'Scar Tissue', 'Californication', "Can't Stop", 'Snow (Hey Oh)', 'Dani California', 'The Zephyr Song', 'By the Way']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results to a big list called `results`.

# %%
artists = ["Red Hot Chili Peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
# Let's look at the second element in the results list.
results[1]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64LkgCfNbLqjclQYCTid8L'},
#      'href': 'https://api.spotify.com/v1/albums/64LkgCfNbLqjclQYCTid8L',
#      'id': '64LkgCfNbLqjclQYCTid8L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732739e569d6b6d0e0abc8cd9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022739e569d6b6d0e0abc8cd9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512739e569d6b6d0e0abc8cd9b',
#        'width': 64}],
#      'name': 'Give Or Take',
#      'release_date': '2022-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:64LkgCfNbLqjclQYCTid8L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 178264,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12107667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5PSYn0XVImstXPFFDtajEK'},
#     'href': 'https://api.spotify.com/v1/tracks/5PSYn0XVImstXPFFDtajEK',
#     'id': '5PSYn0XVImstXPFFDtajEK',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/351df4b9944e433a67a7dcc42e76932041d0421d?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5PSYn0XVImstXPFFDtajEK'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#        'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#        'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#        'name': 'swoozydolphin',
#        'type': 'artist',
#        'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38jv2P71u8Xp4VFJMzAasI'},
#      'href': 'https://api.spotify.com/v1/albums/38jv2P71u8Xp4VFJMzAasI',
#      'id': '38jv2P71u8Xp4VFJMzAasI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345484c4cebd679a9aff90dcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245484c4cebd679a9aff90dcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145484c4cebd679a9aff90dcc',
#        'width': 64}],
#      'name': 'swzgaze',
#      'release_date': '2021-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:38jv2P71u8Xp4VFJMzAasI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#       'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#       'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#       'name': 'swoozydolphin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 99001,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZES82132753'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21hQmHixsf32jwujwGBThB'},
#     'href': 'https://api.spotify.com/v1/tracks/21hQmHixsf32jwujwGBThB',
#     'id': '21hQmHixsf32jwujwGBThB',
#     'is_local': False,
#     'name': 'SCARR',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/42ae140f9721b7ce3afb0f9196ec40d901b6a7b6?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:21hQmHixsf32jwujwGBThB'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l7BJOIRyFkQT9QD96m8tu'},
#        'href': 'https://api.spotify.com/v1/artists/4l7BJOIRyFkQT9QD96m8tu',
#        'id': '4l7BJOIRyFkQT9QD96m8tu',
#        'name': 'Your Stepdad',
#        'type': 'artist',
#        'uri': 'spotify:artist:4l7BJOIRyFkQT9QD96m8tu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4H1r7xLjoAKCQnWjsuL04G'},
#      'href': 'https://api.spotify.com/v1/albums/4H1r7xLjoAKCQnWjsuL04G',
#      'id': '4H1r7xLjoAKCQnWjsuL04G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27367d7c635966e6aa383a164a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0267d7c635966e6aa383a164a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485167d7c635966e6aa383a164a3',
#        'width': 64}],
#      'name': 'sloppy secondaries',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4H1r7xLjoAKCQnWjsuL04G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l7BJOIRyFkQT9QD96m8tu'},
#       'href': 'https://api.spotify.com/v1/artists/4l7BJOIRyFkQT9QD96m8tu',
#       'id': '4l7BJOIRyFkQT9QD96m8tu',
#       'name': 'Your Stepdad',
#       'type': 'artist',
#       'uri': 'spotify:artist:4l7BJOIRyFkQT9QD96m8tu'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 71330,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZNMZ2164330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7kzGbfg49BXcvssmXH4iMC'},
#     'href': 'https://api.spotify.com/v1/tracks/7kzGbfg49BXcvssmXH4iMC',
#     'id': '7kzGbfg49BXcvssmXH4iMC',
#     'is_local': False,
#     'name': 'scar',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/67e161f595eabca0cd066572ed48ed1108ab3109?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7kzGbfg49BXcvssmXH4iMC'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#        'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#        'id': '4IprNlQiJZUUJhDl0fL2SL',
#        'name': 'Quando Rondo',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2s19QcF1PIILzRfS6Jjni3'},
#      'href': 'https://api.spotify.com/v1/albums/2s19QcF1PIILzRfS6Jjni3',
#      'id': '2s19QcF1PIILzRfS6Jjni3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301a870253a90ff8c53dce16e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201a870253a90ff8c53dce16e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101a870253a90ff8c53dce16e',
#        'width': 64}],
#      'name': 'From the Neighborhood to the Stage',
#      'release_date': '2019-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2s19QcF1PIILzRfS6Jjni3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#       'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#       'id': '4IprNlQiJZUUJhDl0fL2SL',
#       'name': 'Quando Rondo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 207000,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21901934'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CFvscpivObLfIVQtHyQxE'},
#     'href': 'https://api.spotify.com/v1/tracks/5CFvscpivObLfIVQtHyQxE',
#     'id': '5CFvscpivObLfIVQtHyQxE',
#     'is_local': False,
#     'name': 'Scarred From Love',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cd34f1df629fe74bb54756566e7d532c181a5530?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5CFvscpivObLfIVQtHyQxE'},
#    {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5COD136qwj9wtuea78EGbF'},
#        'href': 'https://api.spotify.com/v1/artists/5COD136qwj9wtuea78EGbF',
#        'id': '5COD136qwj9wtuea78EGbF',
#        'name': 'Parker Jack',
#        'type': 'artist',
#        'uri': 'spotify:artist:5COD136qwj9wtuea78EGbF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5webehDlzqsSapoO8wmwNA'},
#        'href': 'https://api.spotify.com/v1/artists/5webehDlzqsSapoO8wmwNA',
#        'id': '5webehDlzqsSapoO8wmwNA',
#        'name': 'Chyde',
#        'type': 'artist',
#        'uri': 'spotify:artist:5webehDlzqsSapoO8wmwNA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rrxX9oYAnc4DyFfszt7r4'},
#      'href': 'https://api.spotify.com/v1/albums/6rrxX9oYAnc4DyFfszt7r4',
#      'id': '6rrxX9oYAnc4DyFfszt7r4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a078f9f7c9e941ebd59e87d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a078f9f7c9e941ebd59e87d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a078f9f7c9e941ebd59e87d0',
#        'width': 64}],
#      'name': 'SCARS',
#      'release_date': '2022-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6rrxX9oYAnc4DyFfszt7r4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5COD136qwj9wtuea78EGbF'},
#       'href': 'https://api.spotify.com/v1/artists/5COD136qwj9wtuea78EGbF',
#       'id': '5COD136qwj9wtuea78EGbF',
#       'name': 'Parker Jack',
#       'type': 'artist',
#       'uri': 'spotify:artist:5COD136qwj9wtuea78EGbF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5webehDlzqsSapoO8wmwNA'},
#       'href': 'https://api.spotify.com/v1/artists/5webehDlzqsSapoO8wmwNA',
#       'id': '5webehDlzqsSapoO8wmwNA',
#       'name': 'Chyde',
#       'type': 'artist',
#       'uri': 'spotify:artist:5webehDlzqsSapoO8wmwNA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 173964,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZK6M2276376'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6718FOfpHgSR8fBTaJahHK'},
#     'href': 'https://api.spotify.com/v1/tracks/6718FOfpHgSR8fBTaJahHK',
#     'id': '6718FOfpHgSR8fBTaJahHK',
#     'is_local': False,
#     'name': 'SCARS',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a73a843c53dad7d5cfe99edc9214c21629e73f18?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6718FOfpHgSR8fBTaJahHK'},
#    {'album': {'album_group': 'compilation',
#      'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jVKy4rabu5MaRfG1wJlSs'},
#      'href': 'https://api.spotify.com/v1/albums/5jVKy4rabu5MaRfG1wJlSs',
#      'id': '5jVKy4rabu5MaRfG1wJlSs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737eccf4b2c6097aa1c2d66406',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027eccf4b2c6097aa1c2d66406',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517eccf4b2c6097aa1c2d66406',
#        'width': 64}],
#      'name': 'Lazy Weekend Rap',
#      'release_date': '2023-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:5jVKy4rabu5MaRfG1wJlSs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#       'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#       'id': '4IprNlQiJZUUJhDl0fL2SL',
#       'name': 'Quando Rondo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 207000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21902821'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5SICeLQN6l8Z35joRTpg8A'},
#     'href': 'https://api.spotify.com/v1/tracks/5SICeLQN6l8Z35joRTpg8A',
#     'id': '5SICeLQN6l8Z35joRTpg8A',
#     'is_local': False,
#     'name': 'Scarred from Love',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f4b904b62b5e9541996e5a58d398dd7b45aaaafd?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:5SICeLQN6l8Z35joRTpg8A'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ps6le7tj5BdNtdnfNgTU4'},
#        'href': 'https://api.spotify.com/v1/artists/3Ps6le7tj5BdNtdnfNgTU4',
#        'id': '3Ps6le7tj5BdNtdnfNgTU4',
#        'name': '6 Dogs',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Ps6le7tj5BdNtdnfNgTU4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zrXmqDEqtBFUZo6jedNf0'},
#        'href': 'https://api.spotify.com/v1/artists/6zrXmqDEqtBFUZo6jedNf0',
#        'id': '6zrXmqDEqtBFUZo6jedNf0',
#        'name': 'Danny Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zrXmqDEqtBFUZo6jedNf0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6c7scaeKyXfFQlLzrrE61c'},
#      'href': 'https://api.spotify.com/v1/albums/6c7scaeKyXfFQlLzrrE61c',
#      'id': '6c7scaeKyXfFQlLzrrE61c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e048d70304449b04039456b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e048d70304449b04039456b8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e048d70304449b04039456b8',
#        'width': 64}],
#      'name': '6 Wolves',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:6c7scaeKyXfFQlLzrrE61c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ps6le7tj5BdNtdnfNgTU4'},
#       'href': 'https://api.spotify.com/v1/artists/3Ps6le7tj5BdNtdnfNgTU4',
#       'id': '3Ps6le7tj5BdNtdnfNgTU4',
#       'name': '6 Dogs',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ps6le7tj5BdNtdnfNgTU4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zrXmqDEqtBFUZo6jedNf0'},
#       'href': 'https://api.spotify.com/v1/artists/6zrXmqDEqtBFUZo6jedNf0',
#       'id': '6zrXmqDEqtBFUZo6jedNf0',
#       'name': 'Danny Wolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zrXmqDEqtBFUZo6jedNf0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 148607,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ5FA1752380'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5rnpeh10Rfdw1FEkBWkU7T'},
#     'href': 'https://api.spotify.com/v1/tracks/5rnpeh10Rfdw1FEkBWkU7T',
#     'id': '5rnpeh10Rfdw1FEkBWkU7T',
#     'is_local': False,
#     'name': 'Scar',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b4d9582780c1585b585b8f7fb7e519064626a795?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5rnpeh10Rfdw1FEkBWkU7T'},
#    {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sQHD0DIlJ8oElG6XMO2P3'},
#        'href': 'https://api.spotify.com/v1/artists/1sQHD0DIlJ8oElG6XMO2P3',
#        'id': '1sQHD0DIlJ8oElG6XMO2P3',
#        'name': 'Backdoor Sam',
#        'type': 'artist',
#        'uri': 'spotify:artist:1sQHD0DIlJ8oElG6XMO2P3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
# ...
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 193210,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1415638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57SN8XoR7SWUqWeRMCYAgm'},
#     'href': 'https://api.spotify.com/v1/tracks/57SN8XoR7SWUqWeRMCYAgm',
#     'id': '57SN8XoR7SWUqWeRMCYAgm',
#     'is_local': False,
#     'name': "Scarred Baby's",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8accb43f29dc9315e2ec298c3e869dcffccdeef3?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:57SN8XoR7SWUqWeRMCYAgm'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kUuNU2LRmr9XbwLHXU9UZ'},
#      'href': 'https://api.spotify.com/v1/albums/7kUuNU2LRmr9XbwLHXU9UZ',
#      'id': '7kUuNU2LRmr9XbwLHXU9UZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360e232dede80f62f9bfc8eda',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260e232dede80f62f9bfc8eda',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160e232dede80f62f9bfc8eda',
#        'width': 64}],
#      'name': 'The Lion King: The Gift [Deluxe Edition]',
#      'release_date': '2020-07-31',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7kUuNU2LRmr9XbwLHXU9UZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Zk1DFhCbHY6v3xep2ZjI'},
#       'href': 'https://api.spotify.com/v1/artists/12Zk1DFhCbHY6v3xep2ZjI',
#       'id': '12Zk1DFhCbHY6v3xep2ZjI',
#       'name': '070 Shake',
#       'type': 'artist',
#       'uri': 'spotify:artist:12Zk1DFhCbHY6v3xep2ZjI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3KedxarmBCyFBevnqQHy3P'},
#       'href': 'https://api.spotify.com/v1/artists/3KedxarmBCyFBevnqQHy3P',
#       'id': '3KedxarmBCyFBevnqQHy3P',
#       'name': 'Jessie Reyez',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KedxarmBCyFBevnqQHy3P'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 187334,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11904707'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/08xkNDko1wfeqOZdkCXC9K'},
#     'href': 'https://api.spotify.com/v1/tracks/08xkNDko1wfeqOZdkCXC9K',
#     'id': '08xkNDko1wfeqOZdkCXC9K',
#     'is_local': False,
#     'name': 'SCAR',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f2f569ab95701512a15667deaf3a5a51ab39d50?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:08xkNDko1wfeqOZdkCXC9K'},
#    {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#        'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#        'id': '6HWC3HweNpFwBU00BNVCCq',
#        'name': 'Luke',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7lccXBuQ92VhUbWM2nPQmo'},
#      'href': 'https://api.spotify.com/v1/albums/7lccXBuQ92VhUbWM2nPQmo',
#      'id': '7lccXBuQ92VhUbWM2nPQmo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388e50ceec20521397129c929',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288e50ceec20521397129c929',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188e50ceec20521397129c929',
#        'width': 64}],
#      'name': 'Scandalous - The All Star Compilation',
#      'release_date': '2014',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7lccXBuQ92VhUbWM2nPQmo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#       'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#       'id': '6HWC3HweNpFwBU00BNVCCq',
#       'name': 'Luke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12FHARd9fY0Tu0ila4Ua25'},
#       'href': 'https://api.spotify.com/v1/artists/12FHARd9fY0Tu0ila4Ua25',
#       'id': '12FHARd9fY0Tu0ila4Ua25',
#       'name': 'Trick Daddy',
#       'type': 'artist',
#       'uri': 'spotify:artist:12FHARd9fY0Tu0ila4Ua25'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 206053,
#     'explicit': True,
#     'external_ids': {'isrc': 'USJ3V1822275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0NXA8wKGM6eRgLzpJXanGL'},
#     'href': 'https://api.spotify.com/v1/tracks/0NXA8wKGM6eRgLzpJXanGL',
#     'id': '0NXA8wKGM6eRgLzpJXanGL',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/566da6237fc268cead5a919f192c84e747c5a7df?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0NXA8wKGM6eRgLzpJXanGL'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %% [markdown]
# We can iterate through the `results` list and get just the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Give It Away',
#  'Otherside',
#  'Scar Tissue',
#  'Californication',
#  "Can't Stop",
#  'Snow (Hey Oh)',
#  'Dani California',
#  'The Zephyr Song',
#  'By the Way',
#  'Scarred',
#  'SCARR',
#  'scar',
#  'Scarred From Love',
#  'SCARS',
#  'Scarred from Love',
#  'Scar',
#  "Scarred Baby's",
#  'SCAR',
#  'Scarred',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'I Will Always Love You',
#  'Higher Love',
#  'I Have Nothing',
#  "It's Not Right But It's Okay",
#  'Saving All My Love for You',
#  'How Will I Know',
#  'Greatest Love of All',
#  'Higher Love',
#  'How Will I Know']

# %% [markdown]
# ### Playlists
#
# Using spotipy, we can both build and read spotify playlists. Today, we will only show you how to read information from a playlist. However, if you wish to build one, we strongly encourage you read the [documentation](https://spotipy.readthedocs.io/en/2.19.0/) and explore further.

# %%
my_playlist = sp.user_playlist_tracks(user="spotify", playlist_id="spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8")

# %% [markdown]
# Extract songs ID from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0ce6Rmxf7QXroqa1wzjWY8/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-22T07:34:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#        'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#        'id': '579T5fNgfbDetyamUTAetw',
#        'name': 'S+C+A+R+R',
#        'type': 'artist',
#        'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#      'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#      'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'You\'re the One (From "I Lost My Body")',
#      'release_date': '2019-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 167986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6F31902770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#     'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#     'id': '5Tnx4R7Gwj1LZsfssfzchh',
#     'is_local': False,
#     'name': 'You\'re the One - From "I Lost My Body"',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/613f49f1c8fecb4660754e696bdc2a4b91dae868?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#        'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#        'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#        'name': 'Manchester Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#      'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#      'id': '4hruYceqit29o6m4arpAql',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'A Black Mile To The Surface',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 328933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1702133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#     'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#     'is_local': False,
#     'name': 'The Alien',
#     'popularity': 48,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#        'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#        'id': '1rqPrJjVzB01kfoQpz6XNe',
#        'name': 'Nina & Frederik',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#      'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#      'id': '63obBSI5HlMFoawrrq8RDG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#      'release_date': '1958-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#       'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#       'id': '1rqPrJjVzB01kfoQpz6XNe',
#       'name': 'Nina & Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 145773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560979249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#     'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#     'id': '0R3OcHrzq3f8raukyZgTAc',
#     'is_local': False,
#     'name': 'Oh, Pecador (Oh, Sinne Man)',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d153551fd0ad9886707bb59c83760db3055fe94a?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#        'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#        'id': '2G7QgTep5IsJHGHm1hXygD',
#        'name': 'Kid Francescoli',
#        'type': 'artist',
#        'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#      'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#      'id': '4iII9nfzjxOYQFp8PyV6HD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Play Me Again',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63fbQTZ9yW3SUsBRYcn1Wm'},
#       'href': 'https://api.spotify.com/v1/artists/63fbQTZ9yW3SUsBRYcn1Wm',
#       'id': '63fbQTZ9yW3SUsBRYcn1Wm',
#       'name': 'Julia Minkin',
#       'type': 'artist',
#       'uri': 'spotify:artist:63fbQTZ9yW3SUsBRYcn1Wm'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 390638,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRP621600280'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#     'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#     'id': '24upABZ8A0sAepfu91sEYr',
#     'is_local': False,
#     'name': 'Moon (And It Went Like)',
#     'popularity': 24,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#        'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#        'id': '4aEnNH9PuU1HF3TsZTru54',
#        'name': 'Caribou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#      'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#      'id': '1NqhnYAVqlHuPG2OlgKSZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Never Come Back',
#      'release_date': '2020-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 305480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED622000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#     'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#     'id': '7IBrKDuBlyz3vW9JFCux10',
#     'is_local': False,
#     'name': 'Never Come Back',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#        'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#        'id': '6wH6iStAh4KIaWfuhf0NYM',
#        'name': 'Manu Chao',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#      'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#      'id': '6sLpbLsD1LlXnlCRjt8YuE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Proxima Estacion : Esperanza',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 114920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR84R0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#     'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#     'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#     'is_local': False,
#     'name': 'Trapped By Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:50:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#        'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#        'id': '5v74mT11KGJqadf9sLw4dA',
#        'name': 'Cannonball Adderley',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#      'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#      'id': '5JpHin9lKOyizuJhKxaHWp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Jazz Profile: Cannonball Adderley',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 313200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29000136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#     'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#     'id': '6NF8MZ2trxckVBr82pyyPt',
#     'is_local': False,
#     'name': 'Mercy, Mercy, Mercy',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#        'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#        'id': '3ayds6VIVBx3CU5NSNCDbq',
#        'name': 'Jacques Dutronc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#      'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#      'id': '2S4mgB4hHSszPRGoYrGJ0d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#        'width': 64}],
#      'is_playable': True,
#      'name': "L' aventurier",
#      'release_date': '1969-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 155600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ196900030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#     'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#     'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#     'is_local': False,
#     'name': 'Le responsable',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f57b6b9b44d64ab34f22fd5a1dfe369a2dd6f572?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#        'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#        'id': '2AR42Ur9PcchQDtEdwkv4L',
#        'name': 'Floating Points',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WwZwdTICfaZI51BIIEN9z'},
#      'href': 'https://api.spotify.com/v1/albums/1WwZwdTICfaZI51BIIEN9z',
#      'id': '1WwZwdTICfaZI51BIIEN9z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d03dff7f5eeee485e5a45f62',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d03dff7f5eeee485e5a45f62',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d03dff7f5eeee485e5a45f62',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Crush',
#      'release_date': '2019-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1WwZwdTICfaZI51BIIEN9z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#       'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#       'id': '2AR42Ur9PcchQDtEdwkv4L',
#       'name': 'Floating Points',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
# ...
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2adSO4KU3FDjeM1PXCRDZm'},
#      'href': 'https://api.spotify.com/v1/albums/2adSO4KU3FDjeM1PXCRDZm',
#      'id': '2adSO4KU3FDjeM1PXCRDZm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f461bbc21a9bcec43a926973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f461bbc21a9bcec43a926973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f461bbc21a9bcec43a926973',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Business',
#      'release_date': '2020-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2adSO4KU3FDjeM1PXCRDZm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 164000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA112000624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6f3Slt0GbA2bPZlz0aIFXN'},
#     'href': 'https://api.spotify.com/v1/tracks/6f3Slt0GbA2bPZlz0aIFXN',
#     'id': '6f3Slt0GbA2bPZlz0aIFXN',
#     'is_local': False,
#     'name': 'The Business',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e516723e41dab08c241fc981aeed21407f322d72?cid=e5663f97f8484147b4e34ffc56894d91',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6f3Slt0GbA2bPZlz0aIFXN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/not_invented_here'},
#     'href': 'https://api.spotify.com/v1/users/not_invented_here',
#     'id': 'not_invented_here',
#     'type': 'user',
#     'uri': 'spotify:user:not_invented_here'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#        'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#        'id': '7qmf5YAQYjfjBF9C7kkjzs',
#        'name': 'Johnny Hooker',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#      'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#      'id': '0kelpiZssyYlVNks8cHEth',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#      'release_date': '2015-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#       'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#       'id': '7qmf5YAQYjfjBF9C7kkjzs',
#       'name': 'Johnny Hooker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 285000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh1563538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#     'id': '7uSdpAkxgB0948bW7yjjJO',
#     'is_local': False,
#     'name': 'Amor Marginal',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#     'href': 'https://api.spotify.com/v1/users/shokoshock',
#     'id': 'shokoshock',
#     'type': 'user',
#     'uri': 'spotify:user:shokoshock'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#        'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#        'id': '0YMeriqrS3zgsX24nfY0F0',
#        'name': 'The Tragically Hip',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#      'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#      'id': '6fRGXiRnTyLLRDXpXkrK1n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Yer Favourites',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 225426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM199600015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#     'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#     'id': '5nC2BQzszGGkZi7cvxFzH4',
#     'is_local': False,
#     'name': 'Ahead By A Century',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T13:02:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#     'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#     'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#     'type': 'user',
#     'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#        'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#        'id': '7zsin6IgVsR1rqSRCNYDwq',
#        'name': 'Family of the Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#      'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#      'id': '14SCnv027L0HidHq0URIDu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Loma Vista',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111200237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#     'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#     'id': '6GRDI9suQHikFP6euIXnpq',
#     'is_local': False,
#     'name': 'Hero',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-29T14:22:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#     'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#     'id': '8em1nqrnfspx3alyw0rz3ggn1',
#     'type': 'user',
#     'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#        'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#        'id': '58r1rB5t3VF5X6yXGPequV',
#        'name': 'Maverick City Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#      'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#      'id': '0prxUuXzlIyjSJU9ej003n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Maverick City Vol. 3 Part 1',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#       'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#       'id': '5nO7Yt0Jon48sqKR6VME4T',
#       'name': 'Joe L Barnes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#       'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#       'id': '4rc8nzClXj7sUjvsHVg6AD',
#       'name': 'Naomi Raine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 646239,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2042835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#     'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#     'id': '0aZFEiDKLK2B4gzPaGCZVm',
#     'is_local': False,
#     'name': 'Promises',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 16}

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'

# %% [markdown]
# ### Audio features
#
# You can check an explanation of the audio features [here](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/).

# %%
sp.audio_features("spotify:track:6Sy9BUbgFse0n0LPA5lwy5")
# Out:
# [{'danceability': 0.528,
#   'energy': 0.965,
#   'key': 11,
#   'loudness': -7.984,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.141,
#   'instrumentalness': 0.985,
#   'liveness': 0.0797,
#   'valence': 0.587,
#   'tempo': 136.065,
#   'type': 'audio_features',
#   'id': '6Sy9BUbgFse0n0LPA5lwy5',
#   'uri': 'spotify:track:6Sy9BUbgFse0n0LPA5lwy5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sy9BUbgFse0n0LPA5lwy5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sy9BUbgFse0n0LPA5lwy5',
#   'duration_ms': 225493,
#   'time_signature': 4}]

# %% [markdown]
# ### Creating a function that takes a song name and returns its audio features

# %%
list_of_songs = []

def song_features(human_song_title):
    # Search for the song title you enter into the function, limited to the first 10 results.
    results = sp.search(q=human_song_title, limit = 10)['tracks']['items']
    
    # Create a loop, so we only select the parts of the json we need.
    for i in results:

        # Empty dictionary to be filled with the information below.
        track_dict = {}

        # Add the key artist and a corresponding value to the dictionary.
        track_dict['Artist'] = i['artists'][0]['name']
        # Add the key title and the corresponding value to the dictionary.
        track_dict['Title'] = i['name'] 
        # Add the key album and the corresponding value to the dictionary.
        track_dict['Album'] = i['album']['name']
        # Add the key audio description and the corresponding value to the dictionary.
        track_dict['Audio Description'] = sp.audio_features(i['id'])
        
        # Add the dictionary to the list list_of_songs.
        list_of_songs.append(track_dict)
    # Output list_of_songs.
    return list_of_songs

# Call the function with a song to test.
song_features("Under the Bridge")
# Out:
# [{'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik (Deluxe Edition)',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '3d9DChrdc6BOeFsbrZ3Is0',
#     'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#     'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#     'duration_ms': 264307,
#     'time_signature': 4}]},
#  {'Artist': 'owlh',
#   'Title': 'Under the Bridge',
#   'Album': 'cover to cover',
#   'Audio Description': [{'danceability': 0.781,
#     'energy': 0.355,
#     'key': 9,
#     'loudness': -8.158,
#     'mode': 1,
#     'speechiness': 0.0376,
#     'acousticness': 0.471,
#     'instrumentalness': 0.878,
#     'liveness': 0.125,
#     'valence': 0.363,
#     'tempo': 131.978,
#     'type': 'audio_features',
#     'id': '1AyRpRvLwUwkXwGGuNZHmN',
#     'uri': 'spotify:track:1AyRpRvLwUwkXwGGuNZHmN',
#     'track_href': 'https://api.spotify.com/v1/tracks/1AyRpRvLwUwkXwGGuNZHmN',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AyRpRvLwUwkXwGGuNZHmN',
#     'duration_ms': 244196,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Greatest Hits',
#   'Audio Description': [{'danceability': 0.554,
#     'energy': 0.49,
#     'key': 4,
#     'loudness': -8.046,
#     'mode': 1,
#     'speechiness': 0.0457,
#     'acousticness': 0.0168,
#     'instrumentalness': 0.000534,
#     'liveness': 0.136,
#     'valence': 0.513,
#     'tempo': 84.275,
#     'type': 'audio_features',
#     'id': '23NPGXlSaIqWzvxIRhM2oG',
#     'uri': 'spotify:track:23NPGXlSaIqWzvxIRhM2oG',
#     'track_href': 'https://api.spotify.com/v1/tracks/23NPGXlSaIqWzvxIRhM2oG',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23NPGXlSaIqWzvxIRhM2oG',
#     'duration_ms': 265507,
#     'time_signature': 4}]},
#  {'Artist': 'Adele',
#   'Title': 'Water Under the Bridge',
#   'Album': '25',
#   'Audio Description': [{'danceability': 0.59,
#     'energy': 0.833,
#     'key': 5,
#     'loudness': -6.503,
#     'mode': 0,
#     'speechiness': 0.0615,
#     'acousticness': 0.0142,
#     'instrumentalness': 5.4e-06,
#     'liveness': 0.105,
#     'valence': 0.538,
#     'tempo': 94.963,
#     'type': 'audio_features',
#     'id': '4jL6WWKFDqCOPo2hC3VhSS',
#     'uri': 'spotify:track:4jL6WWKFDqCOPo2hC3VhSS',
#     'track_href': 'https://api.spotify.com/v1/tracks/4jL6WWKFDqCOPo2hC3VhSS',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jL6WWKFDqCOPo2hC3VhSS',
#     'duration_ms': 240439,
#     'time_signature': 4}]},
#  {'Artist': 'Sam Hunt',
#   'Title': 'Water Under The Bridge',
#   'Album': 'Water Under The Bridge',
#   'Audio Description': [{'danceability': 0.635,
#     'energy': 0.866,
#     'key': 5,
#     'loudness': -2.695,
#     'mode': 1,
#     'speechiness': 0.0473,
#     'acousticness': 0.0697,
#     'instrumentalness': 0,
#     'liveness': 0.0955,
#     'valence': 0.853,
#     'tempo': 133.889,
#     'type': 'audio_features',
#     'id': '4viFAHmivkYQKkwLvwKOgg',
#     'uri': 'spotify:track:4viFAHmivkYQKkwLvwKOgg',
#     'track_href': 'https://api.spotify.com/v1/tracks/4viFAHmivkYQKkwLvwKOgg',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4viFAHmivkYQKkwLvwKOgg',
#     'duration_ms': 169760,
#     'time_signature': 4}]},
#  {'Artist': 'Rockabye Baby!',
#   'Title': 'Under the Bridge',
#   'Album': 'Lullaby Renditions of Red Hot Chili Peppers',
#   'Audio Description': [{'danceability': 0.704,
#     'energy': 0.06,
#     'key': 4,
#     'loudness': -21.087,
#     'mode': 1,
#     'speechiness': 0.0907,
#     'acousticness': 0.946,
#     'instrumentalness': 0.912,
#     'liveness': 0.109,
#     'valence': 0.791,
#     'tempo': 158.085,
#     'type': 'audio_features',
#     'id': '45VCZtguiCNu5zJ3YkmcWC',
#     'uri': 'spotify:track:45VCZtguiCNu5zJ3YkmcWC',
#     'track_href': 'https://api.spotify.com/v1/tracks/45VCZtguiCNu5zJ3YkmcWC',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45VCZtguiCNu5zJ3YkmcWC',
#     'duration_ms': 259693,
#     'time_signature': 4}]},
#  {'Artist': 'John Altman',
#   'Title': 'Under The Bridges Of Paris',
#   'Album': 'Shall We Dance?',
#   'Audio Description': [{'danceability': 0.204,
#     'energy': 0.376,
#     'key': 5,
#     'loudness': -11.476,
#     'mode': 1,
#     'speechiness': 0.0345,
#     'acousticness': 0.758,
#     'instrumentalness': 0.496,
#     'liveness': 0.0931,
#     'valence': 0.235,
#     'tempo': 93.075,
#     'type': 'audio_features',
#     'id': '6K7jgMdtOVGQVqHbGAgRuM',
#     'uri': 'spotify:track:6K7jgMdtOVGQVqHbGAgRuM',
#     'track_href': 'https://api.spotify.com/v1/tracks/6K7jgMdtOVGQVqHbGAgRuM',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6K7jgMdtOVGQVqHbGAgRuM',
#     'duration_ms': 180613,
#     'time_signature': 3}]},
#  {'Artist': 'The Drifters',
#   'Title': 'Under the Boardwalk',
#   'Album': 'Under the Boardwalk',
#   'Audio Description': [{'danceability': 0.747,
#     'energy': 0.226,
#     'key': 7,
#     'loudness': -13.635,
#     'mode': 1,
#     'speechiness': 0.0414,
#     'acousticness': 0.908,
#     'instrumentalness': 0.000168,
#     'liveness': 0.107,
#     'valence': 0.778,
#     'tempo': 123.792,
#     'type': 'audio_features',
#     'id': '65jrjEhWfAvysKfnojk1i0',
#     'uri': 'spotify:track:65jrjEhWfAvysKfnojk1i0',
#     'track_href': 'https://api.spotify.com/v1/tracks/65jrjEhWfAvysKfnojk1i0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65jrjEhWfAvysKfnojk1i0',
#     'duration_ms': 161960,
#     'time_signature': 4}]},
#  {'Artist': 'All Saints',
#   'Title': 'Under the Bridge',
#   'Album': 'All Saints',
#   'Audio Description': [{'danceability': 0.717,
#     'energy': 0.564,
#     'key': 6,
#     'loudness': -7.752,
#     'mode': 0,
#     'speechiness': 0.0551,
#     'acousticness': 0.0452,
#     'instrumentalness': 0.000464,
#     'liveness': 0.0897,
#     'valence': 0.728,
#     'tempo': 85.996,
#     'type': 'audio_features',
#     'id': '78M2x5ojbdTmUOpWrbijG3',
#     'uri': 'spotify:track:78M2x5ojbdTmUOpWrbijG3',
#     'track_href': 'https://api.spotify.com/v1/tracks/78M2x5ojbdTmUOpWrbijG3',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78M2x5ojbdTmUOpWrbijG3',
#     'duration_ms': 301067,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '5PclxRY6shIQzSKxxbdZso',
#     'uri': 'spotify:track:5PclxRY6shIQzSKxxbdZso',
#     'track_href': 'https://api.spotify.com/v1/tracks/5PclxRY6shIQzSKxxbdZso',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PclxRY6shIQzSKxxbdZso',
#     'duration_ms': 264307,
#     'time_signature': 4}]}]

# %%
# Make a dataframe from the list of songs created in the function above.
df = pd.DataFrame(list_of_songs)

df
# Out:
#                   Artist                       Title  \
# 0  Red Hot Chili Peppers            Under the Bridge
# 1                   owlh            Under the Bridge
# 2  Red Hot Chili Peppers            Under the Bridge
# 3                  Adele      Water Under the Bridge
# 4               Sam Hunt      Water Under The Bridge
# 5         Rockabye Baby!            Under the Bridge
# 6            John Altman  Under The Bridges Of Paris
# 7           The Drifters         Under the Boardwalk
# 8             All Saints            Under the Bridge
# 9  Red Hot Chili Peppers            Under the Bridge
#
#                                          Album  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)
# 1                               cover to cover
# 2                                Greatest Hits
# 3                                           25
# 4                       Water Under The Bridge
# 5  Lullaby Renditions of Red Hot Chili Peppers
# 6                              Shall We Dance?
# 7                          Under the Boardwalk
# 8                                   All Saints
# 9                        Blood Sugar Sex Magik
#
#                                    Audio Description
# 0  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 1  [{'danceability': 0.781, 'energy': 0.355, 'key...
# 2  [{'danceability': 0.554, 'energy': 0.49, 'key'...
# 3  [{'danceability': 0.59, 'energy': 0.833, 'key'...
# 4  [{'danceability': 0.635, 'energy': 0.866, 'key...
# 5  [{'danceability': 0.704, 'energy': 0.06, 'key'...
# 6  [{'danceability': 0.204, 'energy': 0.376, 'key...
# 7  [{'danceability': 0.747, 'energy': 0.226, 'key...
# 8  [{'danceability': 0.717, 'energy': 0.564, 'key...
# 9  [{'danceability': 0.559, 'energy': 0.345, 'key...

# %% [markdown]
# As you can see, this DataFrame looks a bit off as the audio descriptions aren't expanded - all of the data is clumped together in one cell. Let's correct this, so we can see each audio feature as an individual column.

# %%
# Quick function we can use to select only the first item.
# This can also be done simply with [0], but we wanted to show you how you can incorporate a custom function into your work.

def first_value (x):
    return x[0]

# Making a DataFrame from the audio features of the songs in list_of_songs.
df_audio_features = pd.json_normalize(df['Audio Description'].apply(first_value))

df_audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.559   0.345    4   -13.496     1       0.0459        0.0576
# 1         0.781   0.355    9    -8.158     1       0.0376        0.4710
# 2         0.554   0.490    4    -8.046     1       0.0457        0.0168
# 3         0.590   0.833    5    -6.503     0       0.0615        0.0142
# 4         0.635   0.866    5    -2.695     1       0.0473        0.0697
# 5         0.704   0.060    4   -21.087     1       0.0907        0.9460
# 6         0.204   0.376    5   -11.476     1       0.0345        0.7580
# 7         0.747   0.226    7   -13.635     1       0.0414        0.9080
# 8         0.717   0.564    6    -7.752     0       0.0551        0.0452
# 9         0.559   0.345    4   -13.496     1       0.0459        0.0576
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000105    0.1410    0.458   84.581  audio_features
# 1          0.878000    0.1250    0.363  131.978  audio_features
# 2          0.000534    0.1360    0.513   84.275  audio_features
# 3          0.000005    0.1050    0.538   94.963  audio_features
# 4          0.000000    0.0955    0.853  133.889  audio_features
# 5          0.912000    0.1090    0.791  158.085  audio_features
# 6          0.496000    0.0931    0.235   93.075  audio_features
# 7          0.000168    0.1070    0.778  123.792  audio_features
# 8          0.000464    0.0897    0.728   85.996  audio_features
# 9          0.000105    0.1410    0.458   84.581  audio_features
#
#                        id                                   uri  \
# 0  3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  1AyRpRvLwUwkXwGGuNZHmN  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  23NPGXlSaIqWzvxIRhM2oG  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 3  4jL6WWKFDqCOPo2hC3VhSS  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 4  4viFAHmivkYQKkwLvwKOgg  spotify:track:4viFAHmivkYQKkwLvwKOgg
# 5  45VCZtguiCNu5zJ3YkmcWC  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 6  6K7jgMdtOVGQVqHbGAgRuM  spotify:track:6K7jgMdtOVGQVqHbGAgRuM
# 7  65jrjEhWfAvysKfnojk1i0  spotify:track:65jrjEhWfAvysKfnojk1i0
# 8  78M2x5ojbdTmUOpWrbijG3  spotify:track:78M2x5ojbdTmUOpWrbijG3
# 9  5PclxRY6shIQzSKxxbdZso  spotify:track:5PclxRY6shIQzSKxxbdZso
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 3  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 4  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
# 5  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 6  https://api.spotify.com/v1/tracks/6K7jgMdtOVGQ...
# 7  https://api.spotify.com/v1/tracks/65jrjEhWfAvy...
# 8  https://api.spotify.com/v1/tracks/78M2x5ojbdTm...
# 9  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...       244196
# 2  https://api.spotify.com/v1/audio-analysis/23NP...       265507
# 3  https://api.spotify.com/v1/audio-analysis/4jL6...       240439
# 4  https://api.spotify.com/v1/audio-analysis/4viF...       169760
# 5  https://api.spotify.com/v1/audio-analysis/45VC...       259693
# 6  https://api.spotify.com/v1/audio-analysis/6K7j...       180613
# 7  https://api.spotify.com/v1/audio-analysis/65jr...       161960
# 8  https://api.spotify.com/v1/audio-analysis/78M2...       301067
# 9  https://api.spotify.com/v1/audio-analysis/5Pcl...       264307
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               3
# 7               4
# 8               4
# 9               4

# %%
# Merge the expanded audio features with the original DataFrame.
new_df = pd.merge(df, df_audio_features, left_index=True, right_index=True)

# Drop the old ugly column where all the audio features are clumped together.
new_df.drop('Audio Description', axis=1, inplace=True)

new_df
# Out:
#                   Artist                       Title  \
# 0  Red Hot Chili Peppers            Under the Bridge
# 1                   owlh            Under the Bridge
# 2  Red Hot Chili Peppers            Under the Bridge
# 3                  Adele      Water Under the Bridge
# 4               Sam Hunt      Water Under The Bridge
# 5         Rockabye Baby!            Under the Bridge
# 6            John Altman  Under The Bridges Of Paris
# 7           The Drifters         Under the Boardwalk
# 8             All Saints            Under the Bridge
# 9  Red Hot Chili Peppers            Under the Bridge
#
#                                          Album  danceability  energy  key  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)         0.559   0.345    4
# 1                               cover to cover         0.781   0.355    9
# 2                                Greatest Hits         0.554   0.490    4
# 3                                           25         0.590   0.833    5
# 4                       Water Under The Bridge         0.635   0.866    5
# 5  Lullaby Renditions of Red Hot Chili Peppers         0.704   0.060    4
# 6                              Shall We Dance?         0.204   0.376    5
# 7                          Under the Boardwalk         0.747   0.226    7
# 8                                   All Saints         0.717   0.564    6
# 9                        Blood Sugar Sex Magik         0.559   0.345    4
#
#    loudness  mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
# 1    -8.158     1       0.0376        0.4710  ...    0.1250    0.363  131.978
# 2    -8.046     1       0.0457        0.0168  ...    0.1360    0.513   84.275
# 3    -6.503     0       0.0615        0.0142  ...    0.1050    0.538   94.963
# 4    -2.695     1       0.0473        0.0697  ...    0.0955    0.853  133.889
# 5   -21.087     1       0.0907        0.9460  ...    0.1090    0.791  158.085
# 6   -11.476     1       0.0345        0.7580  ...    0.0931    0.235   93.075
# 7   -13.635     1       0.0414        0.9080  ...    0.1070    0.778  123.792
# 8    -7.752     0       0.0551        0.0452  ...    0.0897    0.728   85.996
# 9   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
#
#              type                      id  \
# 0  audio_features  3d9DChrdc6BOeFsbrZ3Is0
# 1  audio_features  1AyRpRvLwUwkXwGGuNZHmN
# 2  audio_features  23NPGXlSaIqWzvxIRhM2oG
# 3  audio_features  4jL6WWKFDqCOPo2hC3VhSS
# 4  audio_features  4viFAHmivkYQKkwLvwKOgg
# 5  audio_features  45VCZtguiCNu5zJ3YkmcWC
# 6  audio_features  6K7jgMdtOVGQVqHbGAgRuM
# 7  audio_features  65jrjEhWfAvysKfnojk1i0
# 8  audio_features  78M2x5ojbdTmUOpWrbijG3
# 9  audio_features  5PclxRY6shIQzSKxxbdZso
#
#                                     uri  \
# 0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 3  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 4  spotify:track:4viFAHmivkYQKkwLvwKOgg
# 5  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 6  spotify:track:6K7jgMdtOVGQVqHbGAgRuM
# 7  spotify:track:65jrjEhWfAvysKfnojk1i0
# 8  spotify:track:78M2x5ojbdTmUOpWrbijG3
# 9  spotify:track:5PclxRY6shIQzSKxxbdZso
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 3  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 4  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
# 5  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 6  https://api.spotify.com/v1/tracks/6K7jgMdtOVGQ...
# 7  https://api.spotify.com/v1/tracks/65jrjEhWfAvy...
# 8  https://api.spotify.com/v1/tracks/78M2x5ojbdTm...
# 9  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...      264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...      244196
# 2  https://api.spotify.com/v1/audio-analysis/23NP...      265507
# 3  https://api.spotify.com/v1/audio-analysis/4jL6...      240439
# 4  https://api.spotify.com/v1/audio-analysis/4viF...      169760
# 5  https://api.spotify.com/v1/audio-analysis/45VC...      259693
# 6  https://api.spotify.com/v1/audio-analysis/6K7j...      180613
# 7  https://api.spotify.com/v1/audio-analysis/65jr...      161960
# 8  https://api.spotify.com/v1/audio-analysis/78M2...      301067
# 9  https://api.spotify.com/v1/audio-analysis/5Pcl...      264307
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               3
# 7               4
# 8               4
# 9               4
#
# [10 rows x 21 columns]

# %% [markdown]
# If you like a challenge and want to have a go at testing what you've just learned: Follow the steps below and see if you can make a DataFrame similar to the one above with expanded audio features. This time though, do it for a playlist of your choice on spotify. Then see if you can expand it to include the songs from multiple playlists.
#
# Try not to look at the solution, but we've included it below in case you get stuck
#
# ### Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have to be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %% [markdown]
# #### Solution

# %%
list_of_playlists = ["spotify:playlist:2VHdhD77ZP0A3GuJ1MVEfQ",
                    "spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8"]

track_list = []
for i in list_of_playlists:
    individual_playlist = sp.user_playlist_tracks(user="spotify", playlist_id=i)['items']
    for j in individual_playlist:
        track_dict = {}
        track_dict['Artist'] = j['track']['artists'][0]['name']
        track_dict['Title'] = j['track']['name']
        track_dict['Album'] = j['track']['album']['name']
        track_dict['Audio Description'] = sp.audio_features(j['track']['id'])
        track_list.append(track_dict)

print(track_list)
# Out:
# [{'Artist': 'Zack Knight', 'Title': 'Bom Diggy Diggy', 'Album': 'Bom Diggy Diggy (From "Sonu Ke Titu Ki Sweety")', 'Audio Description': [{'danceability': 0.782, 'energy': 0.827, 'key': 11, 'loudness': -4.219, 'mode': 0, 'speechiness': 0.0627, 'acousticness': 0.159, 'instrumentalness': 0, 'liveness': 0.226, 'valence': 0.498, 'tempo': 104.032, 'type': 'audio_features', 'id': '6qCNaRRr5xJALfNJvh0NAw', 'uri': 'spotify:track:6qCNaRRr5xJALfNJvh0NAw', 'track_href': 'https://api.spotify.com/v1/tracks/6qCNaRRr5xJALfNJvh0NAw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qCNaRRr5xJALfNJvh0NAw', 'duration_ms': 238530, 'time_signature': 4}]}, {'Artist': 'Neha Kakkar', 'Title': 'Dilbar', 'Album': 'Satyameva Jayate', 'Audio Description': [{'danceability': 0.725, 'energy': 0.912, 'key': 9, 'loudness': -3.665, 'mode': 0, 'speechiness': 0.0851, 'acousticness': 0.155, 'instrumentalness': 7.68e-05, 'liveness': 0.107, 'valence': 0.674, 'tempo': 104.054, 'type': 'audio_features', 'id': '0Ms1V2flsPzr2bVqImelCB', 'uri': 'spotify:track:0Ms1V2flsPzr2bVqImelCB', 'track_href': 'https://api.spotify.com/v1/tracks/0Ms1V2flsPzr2bVqImelCB', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Ms1V2flsPzr2bVqImelCB', 'duration_ms': 184433, 'time_signature': 4}]}, {'Artist': 'Zack Knight', 'Title': 'Thumka', 'Album': 'Thumka', 'Audio Description': [{'danceability': 0.778, 'energy': 0.801, 'key': 5, 'loudness': -6.456, 'mode': 1, 'speechiness': 0.0758, 'acousticness': 0.0284, 'instrumentalness': 0, 'liveness': 0.327, 'valence': 0.62, 'tempo': 106.061, 'type': 'audio_features', 'id': '7sw49gd22TmoSW3sMGuHbn', 'uri': 'spotify:track:7sw49gd22TmoSW3sMGuHbn', 'track_href': 'https://api.spotify.com/v1/tracks/7sw49gd22TmoSW3sMGuHbn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sw49gd22TmoSW3sMGuHbn', 'duration_ms': 167438, 'time_signature': 4}]}, {'Artist': 'Shreya Ghoshal', 'Title': 'Slow Motion (From "Bharat")', 'Album': 'Slow Motion (From "Bharat")', 'Audio Description': [{'danceability': 0.574, 'energy': 0.738, 'key': 10, 'loudness': -5.526, 'mode': 1, 'speechiness': 0.0958, 'acousticness': 0.0235, 'instrumentalness': 2.03e-06, 'liveness': 0.0959, 'valence': 0.307, 'tempo': 109.996, 'type': 'audio_features', 'id': '7yEuRloGyxyu1KaWBTPP1Z', 'uri': 'spotify:track:7yEuRloGyxyu1KaWBTPP1Z', 'track_href': 'https://api.spotify.com/v1/tracks/7yEuRloGyxyu1KaWBTPP1Z', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7yEuRloGyxyu1KaWBTPP1Z', 'duration_ms': 247248, 'time_signature': 4}]}, {'Artist': 'Aastha Gill', 'Title': 'Kamariya', 'Album': 'Stree', 'Audio Description': [{'danceability': 0.825, 'energy': 0.666, 'key': 4, 'loudness': -4.847, 'mode': 0, 'speechiness': 0.0554, 'acousticness': 0.143, 'instrumentalness': 2.81e-06, 'liveness': 0.237, 'valence': 0.763, 'tempo': 96.987, 'type': 'audio_features', 'id': '5cjVsWqIkBQC7acTRhL0RO', 'uri': 'spotify:track:5cjVsWqIkBQC7acTRhL0RO', 'track_href': 'https://api.spotify.com/v1/tracks/5cjVsWqIkBQC7acTRhL0RO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cjVsWqIkBQC7acTRhL0RO', 'duration_ms': 187983, 'time_signature': 4}]}, {'Artist': 'Darshan Raval', 'Title': 'Chogada (From "Loveyatri")', 'Album': 'Chogada (From "Loveyatri")', 'Audio Description': [{'danceability': 0.359, 'energy': 0.972, 'key': 7, 'loudness': -3.452, 'mode': 1, 'speechiness': 0.109, 'acousticness': 0.136, 'instrumentalness': 2.52e-06, 'liveness': 0.14, 'valence': 0.595, 'tempo': 62.914, 'type': 'audio_features', 'id': '4ymPEyiXabTe1NO8q8EFxG', 'uri': 'spotify:track:4ymPEyiXabTe1NO8q8EFxG', 'track_href': 'https://api.spotify.com/v1/tracks/4ymPEyiXabTe1NO8q8EFxG', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ymPEyiXabTe1NO8q8EFxG', 'duration_ms': 249742, 'time_signature': 4}]}, {'Artist': 'Karan Sehmbi', 'Title': 'Photo (From "Luka Chuppi")', 'Album': 'Photo (From "Luka Chuppi")', 'Audio Description': [{'danceability': 0.739, 'energy': 0.644, 'key': 0, 'loudness': -5.881, 'mode': 0, 's ...

# %%
playlist_df = pd.DataFrame(track_list)

# %%
df_a_f = pd.json_normalize(playlist_df['Audio Description'].apply(first_value))

# %%
new_playlist_df = pd.merge(playlist_df, df_a_f, left_index=True, right_index=True)

# %%
new_playlist_df.drop('Audio Description', axis=1, inplace=True)

# %%
new_playlist_df
# Out:
#                   Artist                        Title  \
# 0            Zack Knight              Bom Diggy Diggy
# 1            Neha Kakkar                       Dilbar
# 2            Zack Knight                       Thumka
# 3         Shreya Ghoshal  Slow Motion (From "Bharat")
# 4            Aastha Gill                     Kamariya
# ..                   ...                          ...
# 111               Tiësto                 The Business
# 112        Johnny Hooker                Amor Marginal
# 113   The Tragically Hip           Ahead By A Century
# 114   Family of the Year                         Hero
# 115  Maverick City Music                     Promises
#
#                                                  Album  danceability  energy  \
# 0      Bom Diggy Diggy (From "Sonu Ke Titu Ki Sweety")         0.782   0.827
# 1                                     Satyameva Jayate         0.725   0.912
# 2                                               Thumka         0.778   0.801
# 3                          Slow Motion (From "Bharat")         0.574   0.738
# 4                                                Stree         0.825   0.666
# ..                                                 ...           ...     ...
# 111                                       The Business         0.798   0.620
# 112  Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!         0.423   0.539
# 113                                     Yer Favourites         0.778   0.628
# 114                                         Loma Vista         0.341   0.539
# 115                        Maverick City Vol. 3 Part 1         0.361   0.423
#
#      key  loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0     11    -4.219     0       0.0627        0.1590  ...    0.2260    0.498
# 1      9    -3.665     0       0.0851        0.1550  ...    0.1070    0.674
# 2      5    -6.456     1       0.0758        0.0284  ...    0.3270    0.620
# 3     10    -5.526     1       0.0958        0.0235  ...    0.0959    0.307
# 4      4    -4.847     0       0.0554        0.1430  ...    0.2370    0.763
# ..   ...       ...   ...          ...           ...  ...       ...      ...
# 111    8    -7.079     0       0.2320        0.4140  ...    0.1120    0.235
# 112    9    -5.722     0       0.0368        0.2520  ...    0.0959    0.196
# 113    7    -7.306     1       0.0275        0.0164  ...    0.0862    0.356
# 114    5    -5.760     1       0.0265        0.2130  ...    0.1090    0.267
# 115   10   -11.697     1       0.0375        0.2830  ...    0.0942    0.238
#
#        tempo            type                      id  \
# 0    104.032  audio_features  6qCNaRRr5xJALfNJvh0NAw
# 1    104.054  audio_features  0Ms1V2flsPzr2bVqImelCB
# 2    106.061  audio_features  7sw49gd22TmoSW3sMGuHbn
# 3    109.996  audio_features  7yEuRloGyxyu1KaWBTPP1Z
# 4     96.987  audio_features  5cjVsWqIkBQC7acTRhL0RO
# ..       ...             ...                     ...
# 111  120.031  audio_features  6f3Slt0GbA2bPZlz0aIFXN
# 112  170.510  audio_features  7uSdpAkxgB0948bW7yjjJO
# 113  126.586  audio_features  5nC2BQzszGGkZi7cvxFzH4
# 114  174.564  audio_features  6GRDI9suQHikFP6euIXnpq
# 115  114.660  audio_features  0aZFEiDKLK2B4gzPaGCZVm
#
#                                       uri  \
# 0    spotify:track:6qCNaRRr5xJALfNJvh0NAw
# 1    spotify:track:0Ms1V2flsPzr2bVqImelCB
# 2    spotify:track:7sw49gd22TmoSW3sMGuHbn
# 3    spotify:track:7yEuRloGyxyu1KaWBTPP1Z
# 4    spotify:track:5cjVsWqIkBQC7acTRhL0RO
# ..                                    ...
# 111  spotify:track:6f3Slt0GbA2bPZlz0aIFXN
# 112  spotify:track:7uSdpAkxgB0948bW7yjjJO
# 113  spotify:track:5nC2BQzszGGkZi7cvxFzH4
# 114  spotify:track:6GRDI9suQHikFP6euIXnpq
# 115  spotify:track:0aZFEiDKLK2B4gzPaGCZVm
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6qCNaRRr5xJA...
# 1    https://api.spotify.com/v1/tracks/0Ms1V2flsPzr...
# 2    https://api.spotify.com/v1/tracks/7sw49gd22Tmo...
# 3    https://api.spotify.com/v1/tracks/7yEuRloGyxyu...
# 4    https://api.spotify.com/v1/tracks/5cjVsWqIkBQC...
# ..                                                 ...
# 111  https://api.spotify.com/v1/tracks/6f3Slt0GbA2b...
# 112  https://api.spotify.com/v1/tracks/7uSdpAkxgB09...
# 113  https://api.spotify.com/v1/tracks/5nC2BQzszGGk...
# 114  https://api.spotify.com/v1/tracks/6GRDI9suQHik...
# 115  https://api.spotify.com/v1/tracks/0aZFEiDKLK2B...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6qCN...      238530
# 1    https://api.spotify.com/v1/audio-analysis/0Ms1...      184433
# 2    https://api.spotify.com/v1/audio-analysis/7sw4...      167438
# 3    https://api.spotify.com/v1/audio-analysis/7yEu...      247248
# 4    https://api.spotify.com/v1/audio-analysis/5cjV...      187983
# ..                                                 ...         ...
# 111  https://api.spotify.com/v1/audio-analysis/6f3S...      164000
# 112  https://api.spotify.com/v1/audio-analysis/7uSd...      285000
# 113  https://api.spotify.com/v1/audio-analysis/5nC2...      225427
# 114  https://api.spotify.com/v1/audio-analysis/6GRD...      190280
# 115  https://api.spotify.com/v1/audio-analysis/0aZF...      646239
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 111               4
# 112               3
# 113               4
# 114               4
# 115               4
#
# [116 rows x 21 columns]
